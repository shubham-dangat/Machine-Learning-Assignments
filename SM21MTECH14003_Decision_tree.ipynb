# %% [markdown]
# # Decision Tree implementation ( without using library sk_learn)

# %% [markdown]
# ### Openning The Wine Data Set

# %% [markdown]
# #### Importing Required Libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# #### Opeening The data set

# %%
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/wine-dataset.csv")

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.head(10)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        0
# 1            6.3              0.30         0.34  ...       0.49      9.5        0
# 2            8.1              0.28         0.40  ...       0.44     10.1        0
# 3            7.2              0.23         0.32  ...       0.40      9.9        0
# 4            7.2              0.23         0.32  ...       0.40      9.9        0
# 5            8.1              0.28         0.40  ...       0.44     10.1        0
# 6            6.2              0.32         0.16  ...       0.47      9.6        0
# 7            7.0              0.27         0.36  ...       0.45      8.8        0
# 8            6.3              0.30         0.34  ...       0.49      9.5        0
# 9            8.1              0.22         0.43  ...       0.45     11.0        0
#
# [10 rows x 12 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         4898 non-null   float64
#  1   volatile acidity      4898 non-null   float64
#  2   citric acid           4898 non-null   float64
#  3   residual sugar        4898 non-null   float64
#  4   chlorides             4898 non-null   float64
#  5   free sulfur dioxide   4898 non-null   float64
#  6   total sulfur dioxide  4898 non-null   float64
#  7   density               4898 non-null   float64
#  8   pH                    4898 non-null   float64
#  9   sulphates             4898 non-null   float64
#  10  alcohol               4898 non-null   float64
#  11  quality               4898 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# ##### Here we can verify there is not any non_null attribute

# %% [markdown]
# ## Implementing Decision Tree

# %% [markdown]
# ### Implementing Entropy Code

# %%
def entropy(col):                                     #to calculate entropy on a given attribute
    counts=np.unique(col,return_counts=True)
    N=float(col.shape[0]) #Counting total elements in array
    ent=0.0
    for ix in counts[1]:
        p=ix/N
        ent +=(-1.0 *p*np.log2(p))
    return ent

# %%
x=np.array([1,1,1,2,2,2])
print("Entropy for sample array [1,1,1,2,2,2]:",entropy(x))
y=np.array([1,1,1])
print(print("Entropy for sample array [1,1,1]:",entropy(y)))
# Out:
# Entropy for sample array [1,1,1,2,2,2]: 1.0
# Entropy for sample array [1,1,1]: 0.0
# None

# %% [markdown]
# #### Above results show correct entropy for given sample data array. So, Let's see entropy of column quality in our dataset

# %%
print(entropy(data['quality']))
# Out:
# 0.7535669054779298

# %% [markdown]
# #### Here we can see that dataset has very high entropy

# %% [markdown]
# ### Implementing Information Gain Using Entropy

# %%
def divide(x_data,key,th_val):                 #to divide the dataset into binary unicariate split on optimal attribute
    x_left=pd.DataFrame([],columns=x_data.columns)
    x_right=pd.DataFrame([],columns=x_data.columns)
    
    for i in range(x_data.shape[0]):
        val=x_data[key].loc[i]
        if(val>th_val):
            x_right=x_right.append(x_data.loc[i])
        else:
            x_left=x_left.append(x_data.loc[i])
    print("Number of nodes in left child: ",x_left.shape[0],"Number of nodes in right child: ",x_right.shape[0])
    return x_left,x_right

# %%
def info_gain(x_data,key,th_val):             # to find information gain of each attribute
    print("Key: \n",key)
    left,right=divide(x_data,key,th_val)
    l=float(left.shape[0]/x_data.shape[0])
    r=float(right.shape[0]/x_data.shape[0])
    if(left.shape[0]==0 or right.shape[0]==0): return -1000000
    i_gain=entropy(x_data.quality)-(l*entropy(left.quality)+r*entropy(right.quality))
    return i_gain

# %%
features=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']                         #storing columns into list called features

# %% [markdown]
# ###  Decision tree code

# %%
class DecisionTree:
    def __init__(self,depth=0,max_depth=5):
        self.left=None
        self.right=None
        self.fkey=None
        self.fval=None
        self.max_depth=max_depth
        self.depth=depth
        self.target=None
    def train(self,x_data):
        features=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
        info_gains=[]
        for i in features:
            i_gain=info_gain(x_data,i,x_data[i].mean())
            info_gains.append(i_gain)
            
        self.fkey=features[np.argmax(info_gains)]
        self.fval=x_data[self.fkey].mean()
        
        print("Optimal attribute to be used to split is :",self.fkey," ",self.depth)
        
        left,right=divide(x_data,self.fkey,self.fval)
        left=left.reset_index(drop=True)
        right=right.reset_index(drop=True)
        
        
        if(left.shape[0]==0 or right.shape[0]==0):
            
            if(x_data.quality.mean()>=0.5):
                self.target=1
            else:
                self.target=0
            return
            
        if(self.depth >=self.max_depth):
            if(x_data.quality.mean()>=0.5):
                self.target=1
            else:
                self.target=0
            return
        
        self.left=DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
        self.left.train(left)
        self.right=DecisionTree(depth=self.depth+1,max_depth=self.max_depth)
        self.right.train(right)
        
        if(x_data.quality.mean()>=0.5):
            self.target=1
        else:
            self.target=0
        return
    
    def predict(self,test):
        if(test[self.fkey]>=self.fval):
            if self.right is None:
                return self.target
            return self.right.predict(test)
        else:
            if self.left is None:
                return self.target
            return self.left.predict(test)

# %% [markdown]
# ### Dividing The Data

# %%
count=int(.7*data.shape[0])
print("Total data rows used for training:", count)
# Out:
# Total data rows used for training: 3428

# %%
train_data=data[0:3428]

# %%
train_data.shape #training data size
# Out:
# (3428, 12)

# %%
test_data=data[3429:] #remaining data for testing

# %% [markdown]
# ### Predicting The Values Using Decision Tree

# %%
dt=DecisionTree()

# %%
dt.train(train_data)           #to train data 70% once
# Out:
# Key:
#  fixed acidity
# Number of nodes in left child:  1938 Number of nodes in right child:  1490
# Key:
#  volatile acidity
# Number of nodes in left child:  1968 Number of nodes in right child:  1460
# Key:
#  citric acid
# Number of nodes in left child:  1979 Number of nodes in right child:  1449
# Key:
#  residual sugar
# Number of nodes in left child:  1925 Number of nodes in right child:  1503
# Key:
#  chlorides
# Number of nodes in left child:  2040 Number of nodes in right child:  1388
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  1843 Number of nodes in right child:  1585
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  1788 Number of nodes in right child:  1640
# Key:
#  density
# Number of nodes in left child:  1799 Number of nodes in right child:  1629
# Key:
#  pH
# Number of nodes in left child:  1820 Number of nodes in right child:  1608
# Key:
#  sulphates
# Number of nodes in left child:  1866 Number of nodes in right child:  1562
# Key:
#  alcohol
# Number of nodes in left child:  1846 Number of nodes in right child:  1582
# Optimal attribute to be used to split is : alcohol   0
# Number of nodes in left child:  1846 Number of nodes in right child:  1582
# Key:
#  fixed acidity
# Number of nodes in left child:  1032 Number of nodes in right child:  814
# Key:
#  volatile acidity
# Number of nodes in left child:  1144 Number of nodes in right child:  702
# Key:
#  citric acid
# Number of nodes in left child:  1054 Number of nodes in right child:  792
# Key:
#  residual sugar
# Number of nodes in left child:  964 Number of nodes in right child:  882
# Key:
#  chlorides
# Number of nodes in left child:  1287 Number of nodes in right child:  559
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  952 Number of nodes in right child:  894
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  924 Number of nodes in right child:  922
# Key:
#  density
# Number of nodes in left child:  968 Number of nodes in right child:  878
# Key:
#  pH
# Number of nodes in left child:  986 Number of nodes in right child:  860
# Key:
#  sulphates
# Number of nodes in left child:  1037 Number of nodes in right child:  809
# Key:
#  alcohol
# Number of nodes in left child:  916 Number of nodes in right child:  930
# Optimal attribute to be used to split is : volatile acidity   1
# Number of nodes in left child:  1144 Number of nodes in right child:  702
# Key:
#  fixed acidity
# Number of nodes in left child:  624 Number of nodes in right child:  520
# Key:
#  volatile acidity
# Number of nodes in left child:  546 Number of nodes in right child:  598
# Key:
#  citric acid
# Number of nodes in left child:  675 Number of nodes in right child:  469
# Key:
#  residual sugar
# Number of nodes in left child:  612 Number of nodes in right child:  532
# Key:
#  chlorides
# Number of nodes in left child:  757 Number of nodes in right child:  387
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  571 Number of nodes in right child:  573
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  565 Number of nodes in right child:  579
# Key:
#  density
# Number of nodes in left child:  610 Number of nodes in right child:  534
# Key:
#  pH
# Number of nodes in left child:  626 Number of nodes in right child:  518
# Key:
#  sulphates
# Number of nodes in left child:  666 Number of nodes in right child:  478
# Key:
#  alcohol
# Number of nodes in left child:  629 Number of nodes in right child:  515
# Optimal attribute to be used to split is : volatile acidity   2
# Number of nodes in left child:  546 Number of nodes in right child:  598
# Key:
#  fixed acidity
# Number of nodes in left child:  275 Number of nodes in right child:  271
# Key:
#  volatile acidity
# Number of nodes in left child:  270 Number of nodes in right child:  276
# Key:
#  citric acid
# Number of nodes in left child:  339 Number of nodes in right child:  207
# Key:
#  residual sugar
# Number of nodes in left child:  296 Number of nodes in right child:  250
# Key:
#  chlorides
# Number of nodes in left child:  353 Number of nodes in right child:  193
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  277 Number of nodes in right child:  269
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  274 Number of nodes in right child:  272
# Key:
#  density
# Number of nodes in left child:  295 Number of nodes in right child:  251
# Key:
#  pH
# Number of nodes in left child:  276 Number of nodes in right child:  270
# Key:
#  sulphates
# Number of nodes in left child:  323 Number of nodes in right child:  223
# Key:
#  alcohol
# Number of nodes in left child:  265 Number of nodes in right child:  281
# Optimal attribute to be used to split is : free sulfur dioxide   3
# Number of nodes in left child:  277 Number of nodes in right child:  269
# Key:
#  fixed acidity
# Number of nodes in left child:  144 Number of nodes in right child:  133
# Key:
#  volatile acidity
# Number of nodes in left child:  113 Number of nodes in right child:  164
# Key:
#  citric acid
# Number of nodes in left child:  174 Number of nodes in right child:  103
# Key:
#  residual sugar
# Number of nodes in left child:  175 Number of nodes in right child:  102
# Key:
#  chlorides
# Number of nodes in left child:  182 Number of nodes in right child:  95
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  135 Number of nodes in right child:  142
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  143 Number of nodes in right child:  134
# Key:
#  density
# Number of nodes in left child:  157 Number of nodes in right child:  120
# Key:
#  pH
# Number of nodes in left child:  133 Number of nodes in right child:  144
# Key:
#  sulphates
# Number of nodes in left child:  164 Number of nodes in right child:  113
# Key:
#  alcohol
# Number of nodes in left child:  127 Number of nodes in right child:  150
# Optimal attribute to be used to split is : sulphates   4
# Number of nodes in left child:  164 Number of nodes in right child:  113
# Key:
#  fixed acidity
# Number of nodes in left child:  90 Number of nodes in right child:  74
# Key:
#  volatile acidity
# Number of nodes in left child:  76 Number of nodes in right child:  88
# Key:
#  citric acid
# Number of nodes in left child:  108 Number of nodes in right child:  56
# Key:
#  residual sugar
# Number of nodes in left child:  110 Number of nodes in right child:  54
# Key:
#  chlorides
# Number of nodes in left child:  121 Number of nodes in right child:  43
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  82 Number of nodes in right child:  82
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  84 Number of nodes in right child:  80
# Key:
#  density
# Number of nodes in left child:  94 Number of nodes in right child:  70
# Key:
#  pH
# Number of nodes in left child:  81 Number of nodes in right child:  83
# Key:
#  sulphates
# Number of nodes in left child:  62 Number of nodes in right child:  102
# Key:
#  alcohol
# Number of nodes in left child:  78 Number of nodes in right child:  86
# Optimal attribute to be used to split is : alcohol   5
# Number of nodes in left child:  78 Number of nodes in right child:  86
# Key:
#  fixed acidity
# Number of nodes in left child:  65 Number of nodes in right child:  48
# Key:
#  volatile acidity
# Number of nodes in left child:  61 Number of nodes in right child:  52
# Key:
#  citric acid
# Number of nodes in left child:  74 Number of nodes in right child:  39
# Key:
#  residual sugar
# Number of nodes in left child:  65 Number of nodes in right child:  48
# Key:
#  chlorides
# Number of nodes in left child:  63 Number of nodes in right child:  50
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  53 Number of nodes in right child:  60
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  63 Number of nodes in right child:  50
# Key:
#  density
# Number of nodes in left child:  58 Number of nodes in right child:  55
# Key:
#  pH
# Number of nodes in left child:  56 Number of nodes in right child:  57
# Key:
#  sulphates
# Number of nodes in left child:  76 Number of nodes in right child:  37
# Key:
#  alcohol
# Number of nodes in left child:  45 Number of nodes in right child:  68
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  63 Number of nodes in right child:  50
# Key:
#  fixed acidity
# Number of nodes in left child:  131 Number of nodes in right child:  138
# Key:
#  volatile acidity
# Number of nodes in left child:  119 Number of nodes in right child:  150
# Key:
#  citric acid
# Number of nodes in left child:  167 Number of nodes in right child:  102
# Key:
#  residual sugar
# Number of nodes in left child:  123 Number of nodes in right child:  146
# Key:
#  chlorides
# Number of nodes in left child:  163 Number of nodes in right child:  106
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  170 Number of nodes in right child:  99
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  150 Number of nodes in right child:  119
# Key:
#  density
# Number of nodes in left child:  129 Number of nodes in right child:  140
# Key:
#  pH
# Number of nodes in left child:  135 Number of nodes in right child:  134
# Key:
#  sulphates
# Number of nodes in left child:  173 Number of nodes in right child:  96
# Key:
#  alcohol
# Number of nodes in left child:  130 Number of nodes in right child:  139
# Optimal attribute to be used to split is : residual sugar   4
# Number of nodes in left child:  123 Number of nodes in right child:  146
# Key:
#  fixed acidity
# Number of nodes in left child:  74 Number of nodes in right child:  49
# Key:
#  volatile acidity
# Number of nodes in left child:  54 Number of nodes in right child:  69
# Key:
#  citric acid
# Number of nodes in left child:  81 Number of nodes in right child:  42
# Key:
#  residual sugar
# Number of nodes in left child:  69 Number of nodes in right child:  54
# Key:
#  chlorides
# Number of nodes in left child:  94 Number of nodes in right child:  29
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  75 Number of nodes in right child:  48
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  72 Number of nodes in right child:  51
# Key:
#  density
# Number of nodes in left child:  61 Number of nodes in right child:  62
# Key:
#  pH
# Number of nodes in left child:  59 Number of nodes in right child:  64
# Key:
#  sulphates
# Number of nodes in left child:  74 Number of nodes in right child:  49
# Key:
#  alcohol
# Number of nodes in left child:  58 Number of nodes in right child:  65
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  72 Number of nodes in right child:  51
# Key:
#  fixed acidity
# Number of nodes in left child:  68 Number of nodes in right child:  78
# Key:
#  volatile acidity
# Number of nodes in left child:  69 Number of nodes in right child:  77
# Key:
#  citric acid
# Number of nodes in left child:  88 Number of nodes in right child:  58
# Key:
#  residual sugar
# Number of nodes in left child:  70 Number of nodes in right child:  76
# Key:
#  chlorides
# Number of nodes in left child:  68 Number of nodes in right child:  78
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  89 Number of nodes in right child:  57
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  80 Number of nodes in right child:  66
# Key:
#  density
# Number of nodes in left child:  68 Number of nodes in right child:  78
# Key:
#  pH
# Number of nodes in left child:  78 Number of nodes in right child:  68
# Key:
#  sulphates
# Number of nodes in left child:  97 Number of nodes in right child:  49
# Key:
#  alcohol
# Number of nodes in left child:  93 Number of nodes in right child:  53
# Optimal attribute to be used to split is : free sulfur dioxide   5
# Number of nodes in left child:  89 Number of nodes in right child:  57
# Key:
#  fixed acidity
# Number of nodes in left child:  326 Number of nodes in right child:  272
# Key:
#  volatile acidity
# Number of nodes in left child:  300 Number of nodes in right child:  298
# Key:
#  citric acid
# Number of nodes in left child:  339 Number of nodes in right child:  259
# Key:
#  residual sugar
# Number of nodes in left child:  316 Number of nodes in right child:  282
# Key:
#  chlorides
# Number of nodes in left child:  417 Number of nodes in right child:  181
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  288 Number of nodes in right child:  310
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  279 Number of nodes in right child:  319
# Key:
#  density
# Number of nodes in left child:  312 Number of nodes in right child:  286
# Key:
#  pH
# Number of nodes in left child:  325 Number of nodes in right child:  273
# Key:
#  sulphates
# Number of nodes in left child:  321 Number of nodes in right child:  277
# Key:
#  alcohol
# Number of nodes in left child:  289 Number of nodes in right child:  309
# Optimal attribute to be used to split is : fixed acidity   3
# Number of nodes in left child:  326 Number of nodes in right child:  272
# Key:
#  fixed acidity
# Number of nodes in left child:  151 Number of nodes in right child:  175
# Key:
#  volatile acidity
# Number of nodes in left child:  155 Number of nodes in right child:  171
# Key:
#  citric acid
# Number of nodes in left child:  191 Number of nodes in right child:  135
# Key:
#  residual sugar
# Number of nodes in left child:  195 Number of nodes in right child:  131
# Key:
#  chlorides
# Number of nodes in left child:  254 Number of nodes in right child:  72
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  162 Number of nodes in right child:  164
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  162 Number of nodes in right child:  164
# Key:
#  density
# Number of nodes in left child:  183 Number of nodes in right child:  143
# Key:
#  pH
# Number of nodes in left child:  185 Number of nodes in right child:  141
# Key:
#  sulphates
# Number of nodes in left child:  174 Number of nodes in right child:  152
# Key:
#  alcohol
# Number of nodes in left child:  163 Number of nodes in right child:  163
# Optimal attribute to be used to split is : alcohol   4
# Number of nodes in left child:  163 Number of nodes in right child:  163
# Key:
#  fixed acidity
# Number of nodes in left child:  82 Number of nodes in right child:  81
# Key:
#  volatile acidity
# Number of nodes in left child:  69 Number of nodes in right child:  94
# Key:
#  citric acid
# Number of nodes in left child:  85 Number of nodes in right child:  78
# Key:
#  residual sugar
# Number of nodes in left child:  102 Number of nodes in right child:  61
# Key:
#  chlorides
# Number of nodes in left child:  131 Number of nodes in right child:  32
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  69 Number of nodes in right child:  94
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  75 Number of nodes in right child:  88
# Key:
#  density
# Number of nodes in left child:  100 Number of nodes in right child:  63
# Key:
#  pH
# Number of nodes in left child:  80 Number of nodes in right child:  83
# Key:
#  sulphates
# Number of nodes in left child:  81 Number of nodes in right child:  82
# Key:
#  alcohol
# Number of nodes in left child:  77 Number of nodes in right child:  86
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  82 Number of nodes in right child:  81
# Key:
#  fixed acidity
# Number of nodes in left child:  69 Number of nodes in right child:  94
# Key:
#  volatile acidity
# Number of nodes in left child:  86 Number of nodes in right child:  77
# Key:
#  citric acid
# Number of nodes in left child:  88 Number of nodes in right child:  75
# Key:
#  residual sugar
# Number of nodes in left child:  78 Number of nodes in right child:  85
# Key:
#  chlorides
# Number of nodes in left child:  109 Number of nodes in right child:  54
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  84 Number of nodes in right child:  79
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  84 Number of nodes in right child:  79
# Key:
#  density
# Number of nodes in left child:  77 Number of nodes in right child:  86
# Key:
#  pH
# Number of nodes in left child:  85 Number of nodes in right child:  78
# Key:
#  sulphates
# Number of nodes in left child:  89 Number of nodes in right child:  74
# Key:
#  alcohol
# Number of nodes in left child:  83 Number of nodes in right child:  80
# Optimal attribute to be used to split is : residual sugar   5
# Number of nodes in left child:  78 Number of nodes in right child:  85
# Key:
#  fixed acidity
# Number of nodes in left child:  162 Number of nodes in right child:  110
# Key:
#  volatile acidity
# Number of nodes in left child:  145 Number of nodes in right child:  127
# Key:
#  citric acid
# Number of nodes in left child:  164 Number of nodes in right child:  108
# Key:
#  residual sugar
# Number of nodes in left child:  119 Number of nodes in right child:  153
# Key:
#  chlorides
# Number of nodes in left child:  147 Number of nodes in right child:  125
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  135 Number of nodes in right child:  137
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  122 Number of nodes in right child:  150
# Key:
#  density
# Number of nodes in left child:  124 Number of nodes in right child:  148
# Key:
#  pH
# Number of nodes in left child:  152 Number of nodes in right child:  120
# Key:
#  sulphates
# Number of nodes in left child:  167 Number of nodes in right child:  105
# Key:
#  alcohol
# Number of nodes in left child:  126 Number of nodes in right child:  146
# Optimal attribute to be used to split is : density   4
# Number of nodes in left child:  124 Number of nodes in right child:  148
# Key:
#  fixed acidity
# Number of nodes in left child:  71 Number of nodes in right child:  53
# Key:
#  volatile acidity
# Number of nodes in left child:  63 Number of nodes in right child:  61
# Key:
#  citric acid
# Number of nodes in left child:  77 Number of nodes in right child:  47
# Key:
#  residual sugar
# Number of nodes in left child:  65 Number of nodes in right child:  59
# Key:
#  chlorides
# Number of nodes in left child:  62 Number of nodes in right child:  62
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  65 Number of nodes in right child:  59
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  61 Number of nodes in right child:  63
# Key:
#  density
# Number of nodes in left child:  55 Number of nodes in right child:  69
# Key:
#  pH
# Number of nodes in left child:  70 Number of nodes in right child:  54
# Key:
#  sulphates
# Number of nodes in left child:  66 Number of nodes in right child:  58
# Key:
#  alcohol
# Number of nodes in left child:  58 Number of nodes in right child:  66
# Optimal attribute to be used to split is : pH   5
# Number of nodes in left child:  70 Number of nodes in right child:  54
# Key:
#  fixed acidity
# Number of nodes in left child:  98 Number of nodes in right child:  50
# Key:
#  volatile acidity
# Number of nodes in left child:  82 Number of nodes in right child:  66
# Key:
#  citric acid
# Number of nodes in left child:  91 Number of nodes in right child:  57
# Key:
#  residual sugar
# Number of nodes in left child:  74 Number of nodes in right child:  74
# Key:
#  chlorides
# Number of nodes in left child:  81 Number of nodes in right child:  67
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  72 Number of nodes in right child:  76
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  70 Number of nodes in right child:  78
# Key:
#  density
# Number of nodes in left child:  95 Number of nodes in right child:  53
# Key:
#  pH
# Number of nodes in left child:  83 Number of nodes in right child:  65
# Key:
#  sulphates
# Number of nodes in left child:  91 Number of nodes in right child:  57
# Key:
#  alcohol
# Number of nodes in left child:  96 Number of nodes in right child:  52
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  70 Number of nodes in right child:  78
# Key:
#  fixed acidity
# Number of nodes in left child:  386 Number of nodes in right child:  316
# Key:
#  volatile acidity
# Number of nodes in left child:  453 Number of nodes in right child:  249
# Key:
#  citric acid
# Number of nodes in left child:  389 Number of nodes in right child:  313
# Key:
#  residual sugar
# Number of nodes in left child:  366 Number of nodes in right child:  336
# Key:
#  chlorides
# Number of nodes in left child:  527 Number of nodes in right child:  175
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  374 Number of nodes in right child:  328
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  353 Number of nodes in right child:  349
# Key:
#  density
# Number of nodes in left child:  347 Number of nodes in right child:  355
# Key:
#  pH
# Number of nodes in left child:  407 Number of nodes in right child:  295
# Key:
#  sulphates
# Number of nodes in left child:  371 Number of nodes in right child:  331
# Key:
#  alcohol
# Number of nodes in left child:  405 Number of nodes in right child:  297
# Optimal attribute to be used to split is : sulphates   2
# Number of nodes in left child:  371 Number of nodes in right child:  331
# Key:
#  fixed acidity
# Number of nodes in left child:  209 Number of nodes in right child:  162
# Key:
#  volatile acidity
# Number of nodes in left child:  245 Number of nodes in right child:  126
# Key:
#  citric acid
# Number of nodes in left child:  215 Number of nodes in right child:  156
# Key:
#  residual sugar
# Number of nodes in left child:  193 Number of nodes in right child:  178
# Key:
#  chlorides
# Number of nodes in left child:  275 Number of nodes in right child:  96
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  203 Number of nodes in right child:  168
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  180 Number of nodes in right child:  191
# Key:
#  density
# Number of nodes in left child:  199 Number of nodes in right child:  172
# Key:
#  pH
# Number of nodes in left child:  197 Number of nodes in right child:  174
# Key:
#  sulphates
# Number of nodes in left child:  162 Number of nodes in right child:  209
# Key:
#  alcohol
# Number of nodes in left child:  185 Number of nodes in right child:  186
# Optimal attribute to be used to split is : pH   3
# Number of nodes in left child:  197 Number of nodes in right child:  174
# Key:
#  fixed acidity
# Number of nodes in left child:  121 Number of nodes in right child:  76
# Key:
#  volatile acidity
# Number of nodes in left child:  136 Number of nodes in right child:  61
# Key:
#  citric acid
# Number of nodes in left child:  99 Number of nodes in right child:  98
# Key:
#  residual sugar
# Number of nodes in left child:  103 Number of nodes in right child:  94
# Key:
#  chlorides
# Number of nodes in left child:  157 Number of nodes in right child:  40
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  106 Number of nodes in right child:  91
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  103 Number of nodes in right child:  94
# Key:
#  density
# Number of nodes in left child:  106 Number of nodes in right child:  91
# Key:
#  pH
# Number of nodes in left child:  72 Number of nodes in right child:  125
# Key:
#  sulphates
# Number of nodes in left child:  83 Number of nodes in right child:  114
# Key:
#  alcohol
# Number of nodes in left child:  102 Number of nodes in right child:  95
# Optimal attribute to be used to split is : fixed acidity   4
# Number of nodes in left child:  121 Number of nodes in right child:  76
# Key:
#  fixed acidity
# Number of nodes in left child:  52 Number of nodes in right child:  69
# Key:
#  volatile acidity
# Number of nodes in left child:  80 Number of nodes in right child:  41
# Key:
#  citric acid
# Number of nodes in left child:  56 Number of nodes in right child:  65
# Key:
#  residual sugar
# Number of nodes in left child:  68 Number of nodes in right child:  53
# Key:
#  chlorides
# Number of nodes in left child:  94 Number of nodes in right child:  27
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  69 Number of nodes in right child:  52
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  64 Number of nodes in right child:  57
# Key:
#  density
# Number of nodes in left child:  63 Number of nodes in right child:  58
# Key:
#  pH
# Number of nodes in left child:  51 Number of nodes in right child:  70
# Key:
#  sulphates
# Number of nodes in left child:  50 Number of nodes in right child:  71
# Key:
#  alcohol
# Number of nodes in left child:  68 Number of nodes in right child:  53
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  52 Number of nodes in right child:  69
# Key:
#  fixed acidity
# Number of nodes in left child:  54 Number of nodes in right child:  22
# Key:
#  volatile acidity
# Number of nodes in left child:  56 Number of nodes in right child:  20
# Key:
#  citric acid
# Number of nodes in left child:  41 Number of nodes in right child:  35
# Key:
#  residual sugar
# Number of nodes in left child:  37 Number of nodes in right child:  39
# Key:
#  chlorides
# Number of nodes in left child:  60 Number of nodes in right child:  16
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  37 Number of nodes in right child:  39
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  33 Number of nodes in right child:  43
# Key:
#  density
# Number of nodes in left child:  46 Number of nodes in right child:  30
# Key:
#  pH
# Number of nodes in left child:  29 Number of nodes in right child:  47
# Key:
#  sulphates
# Number of nodes in left child:  35 Number of nodes in right child:  41
# Key:
#  alcohol
# Number of nodes in left child:  38 Number of nodes in right child:  38
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  54 Number of nodes in right child:  22
# Key:
#  fixed acidity
# Number of nodes in left child:  99 Number of nodes in right child:  75
# Key:
#  volatile acidity
# Number of nodes in left child:  108 Number of nodes in right child:  66
# Key:
#  citric acid
# Number of nodes in left child:  91 Number of nodes in right child:  83
# Key:
#  residual sugar
# Number of nodes in left child:  91 Number of nodes in right child:  83
# Key:
#  chlorides
# Number of nodes in left child:  117 Number of nodes in right child:  57
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  102 Number of nodes in right child:  72
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  91 Number of nodes in right child:  83
# Key:
#  density
# Number of nodes in left child:  97 Number of nodes in right child:  77
# Key:
#  pH
# Number of nodes in left child:  112 Number of nodes in right child:  62
# Key:
#  sulphates
# Number of nodes in left child:  79 Number of nodes in right child:  95
# Key:
#  alcohol
# Number of nodes in left child:  96 Number of nodes in right child:  78
# Optimal attribute to be used to split is : pH   4
# Number of nodes in left child:  112 Number of nodes in right child:  62
# Key:
#  fixed acidity
# Number of nodes in left child:  70 Number of nodes in right child:  42
# Key:
#  volatile acidity
# Number of nodes in left child:  76 Number of nodes in right child:  36
# Key:
#  citric acid
# Number of nodes in left child:  68 Number of nodes in right child:  44
# Key:
#  residual sugar
# Number of nodes in left child:  60 Number of nodes in right child:  52
# Key:
#  chlorides
# Number of nodes in left child:  72 Number of nodes in right child:  40
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  61 Number of nodes in right child:  51
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  56 Number of nodes in right child:  56
# Key:
#  density
# Number of nodes in left child:  64 Number of nodes in right child:  48
# Key:
#  pH
# Number of nodes in left child:  59 Number of nodes in right child:  53
# Key:
#  sulphates
# Number of nodes in left child:  50 Number of nodes in right child:  62
# Key:
#  alcohol
# Number of nodes in left child:  65 Number of nodes in right child:  47
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  70 Number of nodes in right child:  42
# Key:
#  fixed acidity
# Number of nodes in left child:  37 Number of nodes in right child:  25
# Key:
#  volatile acidity
# Number of nodes in left child:  36 Number of nodes in right child:  26
# Key:
#  citric acid
# Number of nodes in left child:  29 Number of nodes in right child:  33
# Key:
#  residual sugar
# Number of nodes in left child:  28 Number of nodes in right child:  34
# Key:
#  chlorides
# Number of nodes in left child:  40 Number of nodes in right child:  22
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  36 Number of nodes in right child:  26
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  35 Number of nodes in right child:  27
# Key:
#  density
# Number of nodes in left child:  31 Number of nodes in right child:  31
# Key:
#  pH
# Number of nodes in left child:  38 Number of nodes in right child:  24
# Key:
#  sulphates
# Number of nodes in left child:  28 Number of nodes in right child:  34
# Key:
#  alcohol
# Number of nodes in left child:  31 Number of nodes in right child:  31
# Optimal attribute to be used to split is : residual sugar   5
# Number of nodes in left child:  28 Number of nodes in right child:  34
# Key:
#  fixed acidity
# Number of nodes in left child:  189 Number of nodes in right child:  142
# Key:
#  volatile acidity
# Number of nodes in left child:  222 Number of nodes in right child:  109
# Key:
#  citric acid
# Number of nodes in left child:  186 Number of nodes in right child:  145
# Key:
#  residual sugar
# Number of nodes in left child:  164 Number of nodes in right child:  167
# Key:
#  chlorides
# Number of nodes in left child:  258 Number of nodes in right child:  73
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  178 Number of nodes in right child:  153
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  163 Number of nodes in right child:  168
# Key:
#  density
# Number of nodes in left child:  145 Number of nodes in right child:  186
# Key:
#  pH
# Number of nodes in left child:  182 Number of nodes in right child:  149
# Key:
#  sulphates
# Number of nodes in left child:  190 Number of nodes in right child:  141
# Key:
#  alcohol
# Number of nodes in left child:  172 Number of nodes in right child:  159
# Optimal attribute to be used to split is : chlorides   3
# Number of nodes in left child:  258 Number of nodes in right child:  73
# Key:
#  fixed acidity
# Number of nodes in left child:  147 Number of nodes in right child:  111
# Key:
#  volatile acidity
# Number of nodes in left child:  175 Number of nodes in right child:  83
# Key:
#  citric acid
# Number of nodes in left child:  150 Number of nodes in right child:  108
# Key:
#  residual sugar
# Number of nodes in left child:  132 Number of nodes in right child:  126
# Key:
#  chlorides
# Number of nodes in left child:  125 Number of nodes in right child:  133
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  142 Number of nodes in right child:  116
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  130 Number of nodes in right child:  128
# Key:
#  density
# Number of nodes in left child:  112 Number of nodes in right child:  146
# Key:
#  pH
# Number of nodes in left child:  140 Number of nodes in right child:  118
# Key:
#  sulphates
# Number of nodes in left child:  137 Number of nodes in right child:  121
# Key:
#  alcohol
# Number of nodes in left child:  140 Number of nodes in right child:  118
# Optimal attribute to be used to split is : volatile acidity   4
# Number of nodes in left child:  175 Number of nodes in right child:  83
# Key:
#  fixed acidity
# Number of nodes in left child:  90 Number of nodes in right child:  85
# Key:
#  volatile acidity
# Number of nodes in left child:  87 Number of nodes in right child:  88
# Key:
#  citric acid
# Number of nodes in left child:  99 Number of nodes in right child:  76
# Key:
#  residual sugar
# Number of nodes in left child:  95 Number of nodes in right child:  80
# Key:
#  chlorides
# Number of nodes in left child:  77 Number of nodes in right child:  98
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  88 Number of nodes in right child:  87
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  85 Number of nodes in right child:  90
# Key:
#  density
# Number of nodes in left child:  84 Number of nodes in right child:  91
# Key:
#  pH
# Number of nodes in left child:  102 Number of nodes in right child:  73
# Key:
#  sulphates
# Number of nodes in left child:  88 Number of nodes in right child:  87
# Key:
#  alcohol
# Number of nodes in left child:  90 Number of nodes in right child:  85
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  90 Number of nodes in right child:  85
# Key:
#  fixed acidity
# Number of nodes in left child:  57 Number of nodes in right child:  26
# Key:
#  volatile acidity
# Number of nodes in left child:  54 Number of nodes in right child:  29
# Key:
#  citric acid
# Number of nodes in left child:  51 Number of nodes in right child:  32
# Key:
#  residual sugar
# Number of nodes in left child:  37 Number of nodes in right child:  46
# Key:
#  chlorides
# Number of nodes in left child:  38 Number of nodes in right child:  45
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  50 Number of nodes in right child:  33
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  42 Number of nodes in right child:  41
# Key:
#  density
# Number of nodes in left child:  38 Number of nodes in right child:  45
# Key:
#  pH
# Number of nodes in left child:  40 Number of nodes in right child:  43
# Key:
#  sulphates
# Number of nodes in left child:  52 Number of nodes in right child:  31
# Key:
#  alcohol
# Number of nodes in left child:  43 Number of nodes in right child:  40
# Optimal attribute to be used to split is : citric acid   5
# Number of nodes in left child:  51 Number of nodes in right child:  32
# Key:
#  fixed acidity
# Number of nodes in left child:  42 Number of nodes in right child:  31
# Key:
#  volatile acidity
# Number of nodes in left child:  46 Number of nodes in right child:  27
# Key:
#  citric acid
# Number of nodes in left child:  35 Number of nodes in right child:  38
# Key:
#  residual sugar
# Number of nodes in left child:  35 Number of nodes in right child:  38
# Key:
#  chlorides
# Number of nodes in left child:  55 Number of nodes in right child:  18
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  36 Number of nodes in right child:  37
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  32 Number of nodes in right child:  41
# Key:
#  density
# Number of nodes in left child:  33 Number of nodes in right child:  40
# Key:
#  pH
# Number of nodes in left child:  39 Number of nodes in right child:  34
# Key:
#  sulphates
# Number of nodes in left child:  48 Number of nodes in right child:  25
# Key:
#  alcohol
# Number of nodes in left child:  42 Number of nodes in right child:  31
# Optimal attribute to be used to split is : fixed acidity   4
# Number of nodes in left child:  42 Number of nodes in right child:  31
# Key:
#  fixed acidity
# Number of nodes in left child:  19 Number of nodes in right child:  23
# Key:
#  volatile acidity
# Number of nodes in left child:  21 Number of nodes in right child:  21
# Key:
#  citric acid
# Number of nodes in left child:  22 Number of nodes in right child:  20
# Key:
#  residual sugar
# Number of nodes in left child:  22 Number of nodes in right child:  20
# Key:
#  chlorides
# Number of nodes in left child:  33 Number of nodes in right child:  9
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  22 Number of nodes in right child:  20
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  18 Number of nodes in right child:  24
# Key:
#  density
# Number of nodes in left child:  20 Number of nodes in right child:  22
# Key:
#  pH
# Number of nodes in left child:  21 Number of nodes in right child:  21
# Key:
#  sulphates
# Number of nodes in left child:  28 Number of nodes in right child:  14
# Key:
#  alcohol
# Number of nodes in left child:  24 Number of nodes in right child:  18
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  19 Number of nodes in right child:  23
# Key:
#  fixed acidity
# Number of nodes in left child:  19 Number of nodes in right child:  12
# Key:
#  volatile acidity
# Number of nodes in left child:  18 Number of nodes in right child:  13
# Key:
#  citric acid
# Number of nodes in left child:  14 Number of nodes in right child:  17
# Key:
#  residual sugar
# Number of nodes in left child:  13 Number of nodes in right child:  18
# Key:
#  chlorides
# Number of nodes in left child:  19 Number of nodes in right child:  12
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  15 Number of nodes in right child:  16
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  16 Number of nodes in right child:  15
# Key:
#  density
# Number of nodes in left child:  13 Number of nodes in right child:  18
# Key:
#  pH
# Number of nodes in left child:  18 Number of nodes in right child:  13
# Key:
#  sulphates
# Number of nodes in left child:  20 Number of nodes in right child:  11
# Key:
#  alcohol
# Number of nodes in left child:  18 Number of nodes in right child:  13
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  19 Number of nodes in right child:  12
# Key:
#  fixed acidity
# Number of nodes in left child:  809 Number of nodes in right child:  773
# Key:
#  volatile acidity
# Number of nodes in left child:  875 Number of nodes in right child:  707
# Key:
#  citric acid
# Number of nodes in left child:  925 Number of nodes in right child:  657
# Key:
#  residual sugar
# Number of nodes in left child:  966 Number of nodes in right child:  616
# Key:
#  chlorides
# Number of nodes in left child:  857 Number of nodes in right child:  725
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  859 Number of nodes in right child:  723
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  831 Number of nodes in right child:  751
# Key:
#  density
# Number of nodes in left child:  891 Number of nodes in right child:  691
# Key:
#  pH
# Number of nodes in left child:  816 Number of nodes in right child:  766
# Key:
#  sulphates
# Number of nodes in left child:  900 Number of nodes in right child:  682
# Key:
#  alcohol
# Number of nodes in left child:  898 Number of nodes in right child:  684
# Optimal attribute to be used to split is : alcohol   1
# Number of nodes in left child:  898 Number of nodes in right child:  684
# Key:
#  fixed acidity
# Number of nodes in left child:  493 Number of nodes in right child:  405
# Key:
#  volatile acidity
# Number of nodes in left child:  537 Number of nodes in right child:  361
# Key:
#  citric acid
# Number of nodes in left child:  489 Number of nodes in right child:  409
# Key:
#  residual sugar
# Number of nodes in left child:  550 Number of nodes in right child:  348
# Key:
#  chlorides
# Number of nodes in left child:  475 Number of nodes in right child:  423
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  474 Number of nodes in right child:  424
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  459 Number of nodes in right child:  439
# Key:
#  density
# Number of nodes in left child:  506 Number of nodes in right child:  392
# Key:
#  pH
# Number of nodes in left child:  474 Number of nodes in right child:  424
# Key:
#  sulphates
# Number of nodes in left child:  481 Number of nodes in right child:  417
# Key:
#  alcohol
# Number of nodes in left child:  475 Number of nodes in right child:  423
# Optimal attribute to be used to split is : alcohol   2
# Number of nodes in left child:  475 Number of nodes in right child:  423
# Key:
#  fixed acidity
# Number of nodes in left child:  273 Number of nodes in right child:  202
# Key:
#  volatile acidity
# Number of nodes in left child:  280 Number of nodes in right child:  195
# Key:
#  citric acid
# Number of nodes in left child:  265 Number of nodes in right child:  210
# Key:
#  residual sugar
# Number of nodes in left child:  272 Number of nodes in right child:  203
# Key:
#  chlorides
# Number of nodes in left child:  227 Number of nodes in right child:  248
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  248 Number of nodes in right child:  227
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  252 Number of nodes in right child:  223
# Key:
#  density
# Number of nodes in left child:  248 Number of nodes in right child:  227
# Key:
#  pH
# Number of nodes in left child:  265 Number of nodes in right child:  210
# Key:
#  sulphates
# Number of nodes in left child:  257 Number of nodes in right child:  218
# Key:
#  alcohol
# Number of nodes in left child:  231 Number of nodes in right child:  244
# Optimal attribute to be used to split is : pH   3
# Number of nodes in left child:  265 Number of nodes in right child:  210
# Key:
#  fixed acidity
# Number of nodes in left child:  145 Number of nodes in right child:  120
# Key:
#  volatile acidity
# Number of nodes in left child:  162 Number of nodes in right child:  103
# Key:
#  citric acid
# Number of nodes in left child:  146 Number of nodes in right child:  119
# Key:
#  residual sugar
# Number of nodes in left child:  146 Number of nodes in right child:  119
# Key:
#  chlorides
# Number of nodes in left child:  147 Number of nodes in right child:  118
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  133 Number of nodes in right child:  132
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  128 Number of nodes in right child:  137
# Key:
#  density
# Number of nodes in left child:  141 Number of nodes in right child:  124
# Key:
#  pH
# Number of nodes in left child:  115 Number of nodes in right child:  150
# Key:
#  sulphates
# Number of nodes in left child:  148 Number of nodes in right child:  117
# Key:
#  alcohol
# Number of nodes in left child:  120 Number of nodes in right child:  145
# Optimal attribute to be used to split is : volatile acidity   4
# Number of nodes in left child:  162 Number of nodes in right child:  103
# Key:
#  fixed acidity
# Number of nodes in left child:  92 Number of nodes in right child:  70
# Key:
#  volatile acidity
# Number of nodes in left child:  76 Number of nodes in right child:  86
# Key:
#  citric acid
# Number of nodes in left child:  94 Number of nodes in right child:  68
# Key:
#  residual sugar
# Number of nodes in left child:  91 Number of nodes in right child:  71
# Key:
#  chlorides
# Number of nodes in left child:  83 Number of nodes in right child:  79
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  90 Number of nodes in right child:  72
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  78 Number of nodes in right child:  84
# Key:
#  density
# Number of nodes in left child:  90 Number of nodes in right child:  72
# Key:
#  pH
# Number of nodes in left child:  64 Number of nodes in right child:  98
# Key:
#  sulphates
# Number of nodes in left child:  90 Number of nodes in right child:  72
# Key:
#  alcohol
# Number of nodes in left child:  75 Number of nodes in right child:  87
# Optimal attribute to be used to split is : volatile acidity   5
# Number of nodes in left child:  76 Number of nodes in right child:  86
# Key:
#  fixed acidity
# Number of nodes in left child:  53 Number of nodes in right child:  50
# Key:
#  volatile acidity
# Number of nodes in left child:  73 Number of nodes in right child:  30
# Key:
#  citric acid
# Number of nodes in left child:  51 Number of nodes in right child:  52
# Key:
#  residual sugar
# Number of nodes in left child:  55 Number of nodes in right child:  48
# Key:
#  chlorides
# Number of nodes in left child:  62 Number of nodes in right child:  41
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  53 Number of nodes in right child:  50
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  55 Number of nodes in right child:  48
# Key:
#  density
# Number of nodes in left child:  56 Number of nodes in right child:  47
# Key:
#  pH
# Number of nodes in left child:  51 Number of nodes in right child:  52
# Key:
#  sulphates
# Number of nodes in left child:  56 Number of nodes in right child:  47
# Key:
#  alcohol
# Number of nodes in left child:  45 Number of nodes in right child:  58
# Optimal attribute to be used to split is : volatile acidity   5
# Number of nodes in left child:  73 Number of nodes in right child:  30
# Key:
#  fixed acidity
# Number of nodes in left child:  91 Number of nodes in right child:  119
# Key:
#  volatile acidity
# Number of nodes in left child:  121 Number of nodes in right child:  89
# Key:
#  citric acid
# Number of nodes in left child:  119 Number of nodes in right child:  91
# Key:
#  residual sugar
# Number of nodes in left child:  130 Number of nodes in right child:  80
# Key:
#  chlorides
# Number of nodes in left child:  100 Number of nodes in right child:  110
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  107 Number of nodes in right child:  103
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  110 Number of nodes in right child:  100
# Key:
#  density
# Number of nodes in left child:  109 Number of nodes in right child:  101
# Key:
#  pH
# Number of nodes in left child:  113 Number of nodes in right child:  97
# Key:
#  sulphates
# Number of nodes in left child:  113 Number of nodes in right child:  97
# Key:
#  alcohol
# Number of nodes in left child:  111 Number of nodes in right child:  99
# Optimal attribute to be used to split is : residual sugar   4
# Number of nodes in left child:  130 Number of nodes in right child:  80
# Key:
#  fixed acidity
# Number of nodes in left child:  56 Number of nodes in right child:  74
# Key:
#  volatile acidity
# Number of nodes in left child:  81 Number of nodes in right child:  49
# Key:
#  citric acid
# Number of nodes in left child:  71 Number of nodes in right child:  59
# Key:
#  residual sugar
# Number of nodes in left child:  80 Number of nodes in right child:  50
# Key:
#  chlorides
# Number of nodes in left child:  64 Number of nodes in right child:  66
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  69 Number of nodes in right child:  61
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  65 Number of nodes in right child:  65
# Key:
#  density
# Number of nodes in left child:  74 Number of nodes in right child:  56
# Key:
#  pH
# Number of nodes in left child:  61 Number of nodes in right child:  69
# Key:
#  sulphates
# Number of nodes in left child:  72 Number of nodes in right child:  58
# Key:
#  alcohol
# Number of nodes in left child:  64 Number of nodes in right child:  66
# Optimal attribute to be used to split is : free sulfur dioxide   5
# Number of nodes in left child:  69 Number of nodes in right child:  61
# Key:
#  fixed acidity
# Number of nodes in left child:  35 Number of nodes in right child:  45
# Key:
#  volatile acidity
# Number of nodes in left child:  41 Number of nodes in right child:  39
# Key:
#  citric acid
# Number of nodes in left child:  48 Number of nodes in right child:  32
# Key:
#  residual sugar
# Number of nodes in left child:  52 Number of nodes in right child:  28
# Key:
#  chlorides
# Number of nodes in left child:  35 Number of nodes in right child:  45
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  44 Number of nodes in right child:  36
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  37 Number of nodes in right child:  43
# Key:
#  density
# Number of nodes in left child:  42 Number of nodes in right child:  38
# Key:
#  pH
# Number of nodes in left child:  50 Number of nodes in right child:  30
# Key:
#  sulphates
# Number of nodes in left child:  41 Number of nodes in right child:  39
# Key:
#  alcohol
# Number of nodes in left child:  47 Number of nodes in right child:  33
# Optimal attribute to be used to split is : chlorides   5
# Number of nodes in left child:  35 Number of nodes in right child:  45
# Key:
#  fixed acidity
# Number of nodes in left child:  220 Number of nodes in right child:  203
# Key:
#  volatile acidity
# Number of nodes in left child:  235 Number of nodes in right child:  188
# Key:
#  citric acid
# Number of nodes in left child:  240 Number of nodes in right child:  183
# Key:
#  residual sugar
# Number of nodes in left child:  283 Number of nodes in right child:  140
# Key:
#  chlorides
# Number of nodes in left child:  231 Number of nodes in right child:  192
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  226 Number of nodes in right child:  197
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  222 Number of nodes in right child:  201
# Key:
#  density
# Number of nodes in left child:  247 Number of nodes in right child:  176
# Key:
#  pH
# Number of nodes in left child:  213 Number of nodes in right child:  210
# Key:
#  sulphates
# Number of nodes in left child:  237 Number of nodes in right child:  186
# Key:
#  alcohol
# Number of nodes in left child:  209 Number of nodes in right child:  214
# Optimal attribute to be used to split is : fixed acidity   3
# Number of nodes in left child:  220 Number of nodes in right child:  203
# Key:
#  fixed acidity
# Number of nodes in left child:  93 Number of nodes in right child:  127
# Key:
#  volatile acidity
# ...
# Optimal attribute to be used to split is : alcohol   2
# Number of nodes in left child:  371 Number of nodes in right child:  313
# Key:
#  fixed acidity
# Number of nodes in left child:  177 Number of nodes in right child:  194
# Key:
#  volatile acidity
# Number of nodes in left child:  212 Number of nodes in right child:  159
# Key:
#  citric acid
# Number of nodes in left child:  222 Number of nodes in right child:  149
# Key:
#  residual sugar
# Number of nodes in left child:  229 Number of nodes in right child:  142
# Key:
#  chlorides
# Number of nodes in left child:  199 Number of nodes in right child:  172
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  187 Number of nodes in right child:  184
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  195 Number of nodes in right child:  176
# Key:
#  density
# Number of nodes in left child:  226 Number of nodes in right child:  145
# Key:
#  pH
# Number of nodes in left child:  202 Number of nodes in right child:  169
# Key:
#  sulphates
# Number of nodes in left child:  227 Number of nodes in right child:  144
# Key:
#  alcohol
# Number of nodes in left child:  164 Number of nodes in right child:  207
# Optimal attribute to be used to split is : pH   3
# Number of nodes in left child:  202 Number of nodes in right child:  169
# Key:
#  fixed acidity
# Number of nodes in left child:  105 Number of nodes in right child:  97
# Key:
#  volatile acidity
# Number of nodes in left child:  109 Number of nodes in right child:  93
# Key:
#  citric acid
# Number of nodes in left child:  104 Number of nodes in right child:  98
# Key:
#  residual sugar
# Number of nodes in left child:  118 Number of nodes in right child:  84
# Key:
#  chlorides
# Number of nodes in left child:  100 Number of nodes in right child:  102
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  92 Number of nodes in right child:  110
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  97 Number of nodes in right child:  105
# Key:
#  density
# Number of nodes in left child:  104 Number of nodes in right child:  98
# Key:
#  pH
# Number of nodes in left child:  85 Number of nodes in right child:  117
# Key:
#  sulphates
# Number of nodes in left child:  118 Number of nodes in right child:  84
# Key:
#  alcohol
# Number of nodes in left child:  85 Number of nodes in right child:  117
# Optimal attribute to be used to split is : alcohol   4
# Number of nodes in left child:  85 Number of nodes in right child:  117
# Key:
#  fixed acidity
# Number of nodes in left child:  49 Number of nodes in right child:  36
# Key:
#  volatile acidity
# Number of nodes in left child:  50 Number of nodes in right child:  35
# Key:
#  citric acid
# Number of nodes in left child:  50 Number of nodes in right child:  35
# Key:
#  residual sugar
# Number of nodes in left child:  47 Number of nodes in right child:  38
# Key:
#  chlorides
# Number of nodes in left child:  51 Number of nodes in right child:  34
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  39 Number of nodes in right child:  46
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  43 Number of nodes in right child:  42
# Key:
#  density
# Number of nodes in left child:  36 Number of nodes in right child:  49
# Key:
#  pH
# Number of nodes in left child:  38 Number of nodes in right child:  47
# Key:
#  sulphates
# Number of nodes in left child:  53 Number of nodes in right child:  32
# Key:
#  alcohol
# Number of nodes in left child:  48 Number of nodes in right child:  37
# Optimal attribute to be used to split is : alcohol   5
# Number of nodes in left child:  48 Number of nodes in right child:  37
# Key:
#  fixed acidity
# Number of nodes in left child:  61 Number of nodes in right child:  56
# Key:
#  volatile acidity
# Number of nodes in left child:  62 Number of nodes in right child:  55
# Key:
#  citric acid
# Number of nodes in left child:  58 Number of nodes in right child:  59
# Key:
#  residual sugar
# Number of nodes in left child:  71 Number of nodes in right child:  46
# Key:
#  chlorides
# Number of nodes in left child:  51 Number of nodes in right child:  66
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  53 Number of nodes in right child:  64
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  55 Number of nodes in right child:  62
# Key:
#  density
# Number of nodes in left child:  69 Number of nodes in right child:  48
# Key:
#  pH
# Number of nodes in left child:  52 Number of nodes in right child:  65
# Key:
#  sulphates
# Number of nodes in left child:  70 Number of nodes in right child:  47
# Key:
#  alcohol
# Number of nodes in left child:  72 Number of nodes in right child:  45
# Optimal attribute to be used to split is : residual sugar   5
# Number of nodes in left child:  71 Number of nodes in right child:  46
# Key:
#  fixed acidity
# Number of nodes in left child:  93 Number of nodes in right child:  76
# Key:
#  volatile acidity
# Number of nodes in left child:  100 Number of nodes in right child:  69
# Key:
#  citric acid
# Number of nodes in left child:  113 Number of nodes in right child:  56
# Key:
#  residual sugar
# Number of nodes in left child:  114 Number of nodes in right child:  55
# Key:
#  chlorides
# Number of nodes in left child:  93 Number of nodes in right child:  76
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  96 Number of nodes in right child:  73
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  90 Number of nodes in right child:  79
# Key:
#  density
# Number of nodes in left child:  116 Number of nodes in right child:  53
# Key:
#  pH
# Number of nodes in left child:  99 Number of nodes in right child:  70
# Key:
#  sulphates
# Number of nodes in left child:  110 Number of nodes in right child:  59
# Key:
#  alcohol
# Number of nodes in left child:  79 Number of nodes in right child:  90
# Optimal attribute to be used to split is : sulphates   4
# Number of nodes in left child:  110 Number of nodes in right child:  59
# Key:
#  fixed acidity
# Number of nodes in left child:  57 Number of nodes in right child:  53
# Key:
#  volatile acidity
# Number of nodes in left child:  68 Number of nodes in right child:  42
# Key:
#  citric acid
# Number of nodes in left child:  68 Number of nodes in right child:  42
# Key:
#  residual sugar
# Number of nodes in left child:  67 Number of nodes in right child:  43
# Key:
#  chlorides
# Number of nodes in left child:  60 Number of nodes in right child:  50
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  58 Number of nodes in right child:  52
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  56 Number of nodes in right child:  54
# Key:
#  density
# Number of nodes in left child:  66 Number of nodes in right child:  44
# Key:
#  pH
# Number of nodes in left child:  64 Number of nodes in right child:  46
# Key:
#  sulphates
# Number of nodes in left child:  51 Number of nodes in right child:  59
# Key:
#  alcohol
# Number of nodes in left child:  50 Number of nodes in right child:  60
# Optimal attribute to be used to split is : volatile acidity   5
# Number of nodes in left child:  68 Number of nodes in right child:  42
# Key:
#  fixed acidity
# Number of nodes in left child:  26 Number of nodes in right child:  33
# Key:
#  volatile acidity
# Number of nodes in left child:  34 Number of nodes in right child:  25
# Key:
#  citric acid
# Number of nodes in left child:  47 Number of nodes in right child:  12
# Key:
#  residual sugar
# Number of nodes in left child:  47 Number of nodes in right child:  12
# Key:
#  chlorides
# Number of nodes in left child:  36 Number of nodes in right child:  23
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  35 Number of nodes in right child:  24
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  36 Number of nodes in right child:  23
# Key:
#  density
# Number of nodes in left child:  44 Number of nodes in right child:  15
# Key:
#  pH
# Number of nodes in left child:  33 Number of nodes in right child:  26
# Key:
#  sulphates
# Number of nodes in left child:  35 Number of nodes in right child:  24
# Key:
#  alcohol
# Number of nodes in left child:  29 Number of nodes in right child:  30
# Optimal attribute to be used to split is : citric acid   5
# Number of nodes in left child:  47 Number of nodes in right child:  12
# Key:
#  fixed acidity
# Number of nodes in left child:  157 Number of nodes in right child:  156
# Key:
#  volatile acidity
# Number of nodes in left child:  154 Number of nodes in right child:  159
# Key:
#  citric acid
# Number of nodes in left child:  186 Number of nodes in right child:  127
# Key:
#  residual sugar
# Number of nodes in left child:  181 Number of nodes in right child:  132
# Key:
#  chlorides
# Number of nodes in left child:  185 Number of nodes in right child:  128
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  171 Number of nodes in right child:  142
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  161 Number of nodes in right child:  152
# Key:
#  density
# Number of nodes in left child:  160 Number of nodes in right child:  153
# Key:
#  pH
# Number of nodes in left child:  162 Number of nodes in right child:  151
# Key:
#  sulphates
# Number of nodes in left child:  179 Number of nodes in right child:  134
# Key:
#  alcohol
# Number of nodes in left child:  175 Number of nodes in right child:  138
# Optimal attribute to be used to split is : citric acid   3
# Number of nodes in left child:  186 Number of nodes in right child:  127
# Key:
#  fixed acidity
# Number of nodes in left child:  95 Number of nodes in right child:  91
# Key:
#  volatile acidity
# Number of nodes in left child:  100 Number of nodes in right child:  86
# Key:
#  citric acid
# Number of nodes in left child:  76 Number of nodes in right child:  110
# Key:
#  residual sugar
# Number of nodes in left child:  108 Number of nodes in right child:  78
# Key:
#  chlorides
# Number of nodes in left child:  85 Number of nodes in right child:  101
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  109 Number of nodes in right child:  77
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  101 Number of nodes in right child:  85
# Key:
#  density
# Number of nodes in left child:  101 Number of nodes in right child:  85
# Key:
#  pH
# Number of nodes in left child:  92 Number of nodes in right child:  94
# Key:
#  sulphates
# Number of nodes in left child:  105 Number of nodes in right child:  81
# Key:
#  alcohol
# Number of nodes in left child:  103 Number of nodes in right child:  83
# Optimal attribute to be used to split is : free sulfur dioxide   4
# Number of nodes in left child:  109 Number of nodes in right child:  77
# Key:
#  fixed acidity
# Number of nodes in left child:  54 Number of nodes in right child:  55
# Key:
#  volatile acidity
# Number of nodes in left child:  61 Number of nodes in right child:  48
# Key:
#  citric acid
# Number of nodes in left child:  43 Number of nodes in right child:  66
# Key:
#  residual sugar
# Number of nodes in left child:  62 Number of nodes in right child:  47
# Key:
#  chlorides
# Number of nodes in left child:  56 Number of nodes in right child:  53
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  46 Number of nodes in right child:  63
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  57 Number of nodes in right child:  52
# Key:
#  density
# Number of nodes in left child:  60 Number of nodes in right child:  49
# Key:
#  pH
# Number of nodes in left child:  53 Number of nodes in right child:  56
# Key:
#  sulphates
# Number of nodes in left child:  59 Number of nodes in right child:  50
# Key:
#  alcohol
# Number of nodes in left child:  74 Number of nodes in right child:  35
# Optimal attribute to be used to split is : sulphates   5
# Number of nodes in left child:  59 Number of nodes in right child:  50
# Key:
#  fixed acidity
# Number of nodes in left child:  36 Number of nodes in right child:  41
# Key:
#  volatile acidity
# Number of nodes in left child:  44 Number of nodes in right child:  33
# Key:
#  citric acid
# Number of nodes in left child:  28 Number of nodes in right child:  49
# Key:
#  residual sugar
# Number of nodes in left child:  44 Number of nodes in right child:  33
# Key:
#  chlorides
# Number of nodes in left child:  36 Number of nodes in right child:  41
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  49 Number of nodes in right child:  28
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  39 Number of nodes in right child:  38
# Key:
#  density
# Number of nodes in left child:  46 Number of nodes in right child:  31
# Key:
#  pH
# Number of nodes in left child:  38 Number of nodes in right child:  39
# Key:
#  sulphates
# Number of nodes in left child:  50 Number of nodes in right child:  27
# Key:
#  alcohol
# Number of nodes in left child:  38 Number of nodes in right child:  39
# Optimal attribute to be used to split is : pH   5
# Number of nodes in left child:  38 Number of nodes in right child:  39
# Key:
#  fixed acidity
# Number of nodes in left child:  64 Number of nodes in right child:  63
# Key:
#  volatile acidity
# Number of nodes in left child:  64 Number of nodes in right child:  63
# Key:
#  citric acid
# Number of nodes in left child:  80 Number of nodes in right child:  47
# Key:
#  residual sugar
# Number of nodes in left child:  73 Number of nodes in right child:  54
# Key:
#  chlorides
# Number of nodes in left child:  79 Number of nodes in right child:  48
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  64 Number of nodes in right child:  63
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  73 Number of nodes in right child:  54
# Key:
#  density
# Number of nodes in left child:  58 Number of nodes in right child:  69
# Key:
#  pH
# Number of nodes in left child:  65 Number of nodes in right child:  62
# Key:
#  sulphates
# Number of nodes in left child:  69 Number of nodes in right child:  58
# Key:
#  alcohol
# Number of nodes in left child:  72 Number of nodes in right child:  55
# Optimal attribute to be used to split is : fixed acidity   4
# Number of nodes in left child:  64 Number of nodes in right child:  63
# Key:
#  fixed acidity
# Number of nodes in left child:  25 Number of nodes in right child:  39
# Key:
#  volatile acidity
# Number of nodes in left child:  36 Number of nodes in right child:  28
# Key:
#  citric acid
# Number of nodes in left child:  44 Number of nodes in right child:  20
# Key:
#  residual sugar
# Number of nodes in left child:  36 Number of nodes in right child:  28
# Key:
#  chlorides
# Number of nodes in left child:  34 Number of nodes in right child:  30
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  27 Number of nodes in right child:  37
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  31 Number of nodes in right child:  33
# Key:
#  density
# Number of nodes in left child:  34 Number of nodes in right child:  30
# Key:
#  pH
# Number of nodes in left child:  39 Number of nodes in right child:  25
# Key:
#  sulphates
# Number of nodes in left child:  37 Number of nodes in right child:  27
# Key:
#  alcohol
# Number of nodes in left child:  34 Number of nodes in right child:  30
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  25 Number of nodes in right child:  39
# Key:
#  fixed acidity
# Number of nodes in left child:  33 Number of nodes in right child:  30
# Key:
#  volatile acidity
# Number of nodes in left child:  28 Number of nodes in right child:  35
# Key:
#  citric acid
# Number of nodes in left child:  41 Number of nodes in right child:  22
# Key:
#  residual sugar
# Number of nodes in left child:  37 Number of nodes in right child:  26
# Key:
#  chlorides
# Number of nodes in left child:  40 Number of nodes in right child:  23
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  36 Number of nodes in right child:  27
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  35 Number of nodes in right child:  28
# Key:
#  density
# Number of nodes in left child:  37 Number of nodes in right child:  26
# Key:
#  pH
# Number of nodes in left child:  32 Number of nodes in right child:  31
# Key:
#  sulphates
# Number of nodes in left child:  35 Number of nodes in right child:  28
# Key:
#  alcohol
# Number of nodes in left child:  38 Number of nodes in right child:  25
# Optimal attribute to be used to split is : residual sugar   5
# Number of nodes in left child:  37 Number of nodes in right child:  26

# %% [markdown]
# ### Predicting The Values

# %%
dt.predict(test_data.loc[4004]) #to print predicted value of entered row
# Out:
# 1

# %%
test_data['quality'].loc[4004]  #to print actual value of entered row
# Out:
# 1

# %%
test_data1=test_data.reset_index(drop=True)

# %%
for i in range(test_data1.shape[0]):             #to test the remaining 30% of data
    test_data1['predicted_output']=dt.predict(test_data1.loc[i])

# %%
test_data1.head(10) #prints some sample predicted output
# Out:
#    fixed acidity  volatile acidity  ...  quality  predicted_output
# 0            7.1             0.180  ...        0                 0
# 1            7.1             0.170  ...        0                 0
# 2            7.1             0.180  ...        0                 0
# 3            7.8             0.290  ...        0                 0
# 4            6.2             0.255  ...        1                 0
# 5            8.2             0.340  ...        0                 0
# 6            6.5             0.240  ...        0                 0
# 7            6.9             0.240  ...        0                 0
# 8            6.7             0.400  ...        0                 0
# 9            6.7             0.300  ...        0                 0
#
# [10 rows x 13 columns]

# %%
accuracy=np.sum(test_data1['quality']==test_data1['predicted_output'])/test_data1.shape[0]

# %%
print(accuracy)   #accuracy after 1 fold
# Out:
# 0.7930565010211028

# %% [markdown]
# Here using early stopping , accuracy of code is shown above

# %% [markdown]
# # Cross Validation

# %% [markdown]
# ### Considering K value as 10 we divide data in 10 parts

# %%
size_of_each_part=data.shape[0]/10
print(size_of_each_part)
# Out:
# 489.8

# %%
def accuracy(test_data):
    test_data1=test_data.reset_index(drop=True)
    for i in range(test_data1.shape[0]):
        test_data1['predicted_output']=dt.predict(test_data1.loc[i])
    accuracy=np.sum(test_data1['quality']==test_data1['predicted_output'])/test_data1.shape[0]
    return accuracy

# %%
def training_kfold(test_data,train_data,accuracy_list,count):
    test_data.reset_index(drop=True,inplace=True)
    train_data.reset_index(drop=True,inplace=True)
    print(count," "," Training Start")
    dt.train(train_data)
    print("Training Complete\n")
    accuracy_list.append(accuracy(test_data))

# %%
arr=[]
k=0
while k<4890:
    arr.append(k)
    k=k+489

# %%
print(arr)
# Out:
# [0, 489, 978, 1467, 1956, 2445, 2934, 3423, 3912, 4401]

# %%
count=0
accuracy_list=[]
for k in arr:
    test_data=data[k:k+488]
    if(k==0):
        train_data=data[k+489:]
    else:
        train_data=data[:k-1].append(data[k+490:])
    count=count+1
    training_kfold(test_data,train_data,accuracy_list,count)
# Out:
# Streaming output truncated to the last 5000 lines.
#  chlorides
# Number of nodes in left child:  71 Number of nodes in right child:  56
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  69 Number of nodes in right child:  58
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  69 Number of nodes in right child:  58
# Key:
#  density
# Number of nodes in left child:  67 Number of nodes in right child:  60
# Key:
#  pH
# Number of nodes in left child:  70 Number of nodes in right child:  57
# Key:
#  sulphates
# Number of nodes in left child:  71 Number of nodes in right child:  56
# Key:
#  alcohol
# Number of nodes in left child:  60 Number of nodes in right child:  67
# Optimal attribute to be used to split is : alcohol   5
# Number of nodes in left child:  60 Number of nodes in right child:  67
# Key:
#  fixed acidity
# Number of nodes in left child:  65 Number of nodes in right child:  59
# Key:
#  volatile acidity
# Number of nodes in left child:  73 Number of nodes in right child:  51
# Key:
#  citric acid
# Number of nodes in left child:  57 Number of nodes in right child:  67
# Key:
#  residual sugar
# Number of nodes in left child:  66 Number of nodes in right child:  58
# Key:
#  chlorides
# Number of nodes in left child:  66 Number of nodes in right child:  58
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  65 Number of nodes in right child:  59
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  64 Number of nodes in right child:  60
# Key:
#  density
# Number of nodes in left child:  67 Number of nodes in right child:  57
# Key:
#  pH
# Number of nodes in left child:  71 Number of nodes in right child:  53
# Key:
#  sulphates
# Number of nodes in left child:  70 Number of nodes in right child:  54
# Key:
#  alcohol
# Number of nodes in left child:  54 Number of nodes in right child:  70
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  65 Number of nodes in right child:  59
# Key:
#  fixed acidity
# Number of nodes in left child:  438 Number of nodes in right child:  450
# Key:
#  volatile acidity
# Number of nodes in left child:  494 Number of nodes in right child:  394
# Key:
#  citric acid
# Number of nodes in left child:  506 Number of nodes in right child:  382
# Key:
#  residual sugar
# Number of nodes in left child:  555 Number of nodes in right child:  333
# Key:
#  chlorides
# Number of nodes in left child:  521 Number of nodes in right child:  367
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  477 Number of nodes in right child:  411
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  482 Number of nodes in right child:  406
# Key:
#  density
# Number of nodes in left child:  507 Number of nodes in right child:  381
# Key:
#  pH
# Number of nodes in left child:  459 Number of nodes in right child:  429
# Key:
#  sulphates
# Number of nodes in left child:  546 Number of nodes in right child:  342
# Key:
#  alcohol
# Number of nodes in left child:  482 Number of nodes in right child:  406
# Optimal attribute to be used to split is : volatile acidity   2
# Number of nodes in left child:  494 Number of nodes in right child:  394
# Key:
#  fixed acidity
# Number of nodes in left child:  256 Number of nodes in right child:  238
# Key:
#  volatile acidity
# Number of nodes in left child:  219 Number of nodes in right child:  275
# Key:
#  citric acid
# Number of nodes in left child:  306 Number of nodes in right child:  188
# Key:
#  residual sugar
# Number of nodes in left child:  330 Number of nodes in right child:  164
# Key:
#  chlorides
# Number of nodes in left child:  276 Number of nodes in right child:  218
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  274 Number of nodes in right child:  220
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  276 Number of nodes in right child:  218
# Key:
#  density
# Number of nodes in left child:  273 Number of nodes in right child:  221
# Key:
#  pH
# Number of nodes in left child:  250 Number of nodes in right child:  244
# Key:
#  sulphates
# Number of nodes in left child:  294 Number of nodes in right child:  200
# Key:
#  alcohol
# Number of nodes in left child:  272 Number of nodes in right child:  222
# Optimal attribute to be used to split is : pH   3
# Number of nodes in left child:  250 Number of nodes in right child:  244
# Key:
#  fixed acidity
# Number of nodes in left child:  133 Number of nodes in right child:  117
# Key:
#  volatile acidity
# Number of nodes in left child:  107 Number of nodes in right child:  143
# Key:
#  citric acid
# Number of nodes in left child:  147 Number of nodes in right child:  103
# Key:
#  residual sugar
# Number of nodes in left child:  170 Number of nodes in right child:  80
# Key:
#  chlorides
# Number of nodes in left child:  128 Number of nodes in right child:  122
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  122 Number of nodes in right child:  128
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  133 Number of nodes in right child:  117
# Key:
#  density
# Number of nodes in left child:  146 Number of nodes in right child:  104
# Key:
#  pH
# Number of nodes in left child:  118 Number of nodes in right child:  132
# Key:
#  sulphates
# Number of nodes in left child:  152 Number of nodes in right child:  98
# Key:
#  alcohol
# Number of nodes in left child:  138 Number of nodes in right child:  112
# Optimal attribute to be used to split is : alcohol   4
# Number of nodes in left child:  138 Number of nodes in right child:  112
# Key:
#  fixed acidity
# Number of nodes in left child:  76 Number of nodes in right child:  62
# Key:
#  volatile acidity
# Number of nodes in left child:  65 Number of nodes in right child:  73
# Key:
#  citric acid
# Number of nodes in left child:  73 Number of nodes in right child:  65
# Key:
#  residual sugar
# Number of nodes in left child:  91 Number of nodes in right child:  47
# Key:
#  chlorides
# Number of nodes in left child:  63 Number of nodes in right child:  75
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  68 Number of nodes in right child:  70
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  73 Number of nodes in right child:  65
# Key:
#  density
# Number of nodes in left child:  88 Number of nodes in right child:  50
# Key:
#  pH
# Number of nodes in left child:  67 Number of nodes in right child:  71
# Key:
#  sulphates
# Number of nodes in left child:  83 Number of nodes in right child:  55
# Key:
#  alcohol
# Number of nodes in left child:  67 Number of nodes in right child:  71
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  73 Number of nodes in right child:  65
# Key:
#  fixed acidity
# Number of nodes in left child:  53 Number of nodes in right child:  59
# Key:
#  volatile acidity
# Number of nodes in left child:  42 Number of nodes in right child:  70
# Key:
#  citric acid
# Number of nodes in left child:  67 Number of nodes in right child:  45
# Key:
#  residual sugar
# Number of nodes in left child:  73 Number of nodes in right child:  39
# Key:
#  chlorides
# Number of nodes in left child:  65 Number of nodes in right child:  47
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  62 Number of nodes in right child:  50
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  67 Number of nodes in right child:  45
# Key:
#  density
# Number of nodes in left child:  61 Number of nodes in right child:  51
# Key:
#  pH
# Number of nodes in left child:  53 Number of nodes in right child:  59
# Key:
#  sulphates
# Number of nodes in left child:  69 Number of nodes in right child:  43
# Key:
#  alcohol
# Number of nodes in left child:  62 Number of nodes in right child:  50
# Optimal attribute to be used to split is : chlorides   5
# Number of nodes in left child:  65 Number of nodes in right child:  47
# Key:
#  fixed acidity
# Number of nodes in left child:  132 Number of nodes in right child:  112
# Key:
#  volatile acidity
# Number of nodes in left child:  112 Number of nodes in right child:  132
# Key:
#  citric acid
# Number of nodes in left child:  159 Number of nodes in right child:  85
# Key:
#  residual sugar
# Number of nodes in left child:  163 Number of nodes in right child:  81
# Key:
#  chlorides
# Number of nodes in left child:  131 Number of nodes in right child:  113
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  135 Number of nodes in right child:  109
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  143 Number of nodes in right child:  101
# Key:
#  density
# Number of nodes in left child:  127 Number of nodes in right child:  117
# Key:
#  pH
# Number of nodes in left child:  143 Number of nodes in right child:  101
# Key:
#  sulphates
# Number of nodes in left child:  153 Number of nodes in right child:  91
# Key:
#  alcohol
# Number of nodes in left child:  133 Number of nodes in right child:  111
# Optimal attribute to be used to split is : alcohol   4
# Number of nodes in left child:  133 Number of nodes in right child:  111
# Key:
#  fixed acidity
# Number of nodes in left child:  71 Number of nodes in right child:  62
# Key:
#  volatile acidity
# Number of nodes in left child:  66 Number of nodes in right child:  67
# Key:
#  citric acid
# Number of nodes in left child:  95 Number of nodes in right child:  38
# Key:
#  residual sugar
# Number of nodes in left child:  90 Number of nodes in right child:  43
# Key:
#  chlorides
# Number of nodes in left child:  69 Number of nodes in right child:  64
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  74 Number of nodes in right child:  59
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  75 Number of nodes in right child:  58
# Key:
#  density
# Number of nodes in left child:  79 Number of nodes in right child:  54
# Key:
#  pH
# Number of nodes in left child:  80 Number of nodes in right child:  53
# Key:
#  sulphates
# Number of nodes in left child:  87 Number of nodes in right child:  46
# Key:
#  alcohol
# Number of nodes in left child:  70 Number of nodes in right child:  63
# Optimal attribute to be used to split is : sulphates   5
# Number of nodes in left child:  87 Number of nodes in right child:  46
# Key:
#  fixed acidity
# Number of nodes in left child:  66 Number of nodes in right child:  45
# Key:
#  volatile acidity
# Number of nodes in left child:  48 Number of nodes in right child:  63
# Key:
#  citric acid
# Number of nodes in left child:  69 Number of nodes in right child:  42
# Key:
#  residual sugar
# Number of nodes in left child:  75 Number of nodes in right child:  36
# Key:
#  chlorides
# Number of nodes in left child:  59 Number of nodes in right child:  52
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  63 Number of nodes in right child:  48
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  63 Number of nodes in right child:  48
# Key:
#  density
# Number of nodes in left child:  72 Number of nodes in right child:  39
# Key:
#  pH
# Number of nodes in left child:  63 Number of nodes in right child:  48
# Key:
#  sulphates
# Number of nodes in left child:  68 Number of nodes in right child:  43
# Key:
#  alcohol
# Number of nodes in left child:  64 Number of nodes in right child:  47
# Optimal attribute to be used to split is : free sulfur dioxide   5
# Number of nodes in left child:  63 Number of nodes in right child:  48
# Key:
#  fixed acidity
# Number of nodes in left child:  182 Number of nodes in right child:  212
# Key:
#  volatile acidity
# Number of nodes in left child:  254 Number of nodes in right child:  140
# Key:
#  citric acid
# Number of nodes in left child:  211 Number of nodes in right child:  183
# Key:
#  residual sugar
# Number of nodes in left child:  242 Number of nodes in right child:  152
# Key:
#  chlorides
# Number of nodes in left child:  221 Number of nodes in right child:  173
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  207 Number of nodes in right child:  187
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  196 Number of nodes in right child:  198
# Key:
#  density
# Number of nodes in left child:  224 Number of nodes in right child:  170
# Key:
#  pH
# Number of nodes in left child:  209 Number of nodes in right child:  185
# Key:
#  sulphates
# Number of nodes in left child:  237 Number of nodes in right child:  157
# Key:
#  alcohol
# Number of nodes in left child:  209 Number of nodes in right child:  185
# Optimal attribute to be used to split is : free sulfur dioxide   3
# Number of nodes in left child:  207 Number of nodes in right child:  187
# Key:
#  fixed acidity
# Number of nodes in left child:  103 Number of nodes in right child:  104
# Key:
#  volatile acidity
# Number of nodes in left child:  126 Number of nodes in right child:  81
# Key:
#  citric acid
# Number of nodes in left child:  102 Number of nodes in right child:  105
# Key:
#  residual sugar
# Number of nodes in left child:  129 Number of nodes in right child:  78
# Key:
#  chlorides
# Number of nodes in left child:  131 Number of nodes in right child:  76
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  95 Number of nodes in right child:  112
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  116 Number of nodes in right child:  91
# Key:
#  density
# Number of nodes in left child:  125 Number of nodes in right child:  82
# Key:
#  pH
# Number of nodes in left child:  106 Number of nodes in right child:  101
# Key:
#  sulphates
# Number of nodes in left child:  118 Number of nodes in right child:  89
# Key:
#  alcohol
# Number of nodes in left child:  102 Number of nodes in right child:  105
# Optimal attribute to be used to split is : free sulfur dioxide   4
# Number of nodes in left child:  95 Number of nodes in right child:  112
# Key:
#  fixed acidity
# Number of nodes in left child:  55 Number of nodes in right child:  40
# Key:
#  volatile acidity
# Number of nodes in left child:  65 Number of nodes in right child:  30
# Key:
#  citric acid
# Number of nodes in left child:  45 Number of nodes in right child:  50
# Key:
#  residual sugar
# Number of nodes in left child:  65 Number of nodes in right child:  30
# Key:
#  chlorides
# Number of nodes in left child:  58 Number of nodes in right child:  37
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  35 Number of nodes in right child:  60
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  53 Number of nodes in right child:  42
# Key:
#  density
# Number of nodes in left child:  67 Number of nodes in right child:  28
# Key:
#  pH
# Number of nodes in left child:  47 Number of nodes in right child:  48
# Key:
#  sulphates
# Number of nodes in left child:  57 Number of nodes in right child:  38
# Key:
#  alcohol
# Number of nodes in left child:  43 Number of nodes in right child:  52
# Optimal attribute to be used to split is : density   5
# Number of nodes in left child:  67 Number of nodes in right child:  28
# Key:
#  fixed acidity
# Number of nodes in left child:  53 Number of nodes in right child:  59
# Key:
#  volatile acidity
# Number of nodes in left child:  64 Number of nodes in right child:  48
# Key:
#  citric acid
# Number of nodes in left child:  57 Number of nodes in right child:  55
# Key:
#  residual sugar
# Number of nodes in left child:  67 Number of nodes in right child:  45
# Key:
#  chlorides
# Number of nodes in left child:  69 Number of nodes in right child:  43
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  59 Number of nodes in right child:  53
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  60 Number of nodes in right child:  52
# Key:
#  density
# Number of nodes in left child:  56 Number of nodes in right child:  56
# Key:
#  pH
# Number of nodes in left child:  60 Number of nodes in right child:  52
# Key:
#  sulphates
# Number of nodes in left child:  61 Number of nodes in right child:  51
# Key:
#  alcohol
# Number of nodes in left child:  59 Number of nodes in right child:  53
# Optimal attribute to be used to split is : chlorides   5
# Number of nodes in left child:  69 Number of nodes in right child:  43
# Key:
#  fixed acidity
# Number of nodes in left child:  95 Number of nodes in right child:  92
# Key:
#  volatile acidity
# Number of nodes in left child:  120 Number of nodes in right child:  67
# Key:
#  citric acid
# Number of nodes in left child:  115 Number of nodes in right child:  72
# Key:
#  residual sugar
# Number of nodes in left child:  115 Number of nodes in right child:  72
# Key:
#  chlorides
# Number of nodes in left child:  102 Number of nodes in right child:  85
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  115 Number of nodes in right child:  72
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  99 Number of nodes in right child:  88
# Key:
#  density
# Number of nodes in left child:  95 Number of nodes in right child:  92
# Key:
#  pH
# Number of nodes in left child:  105 Number of nodes in right child:  82
# Key:
#  sulphates
# Number of nodes in left child:  104 Number of nodes in right child:  83
# Key:
#  alcohol
# Number of nodes in left child:  107 Number of nodes in right child:  80
# Optimal attribute to be used to split is : chlorides   4
# Number of nodes in left child:  102 Number of nodes in right child:  85
# Key:
#  fixed acidity
# Number of nodes in left child:  45 Number of nodes in right child:  57
# Key:
#  volatile acidity
# Number of nodes in left child:  67 Number of nodes in right child:  35
# Key:
#  citric acid
# Number of nodes in left child:  60 Number of nodes in right child:  42
# Key:
#  residual sugar
# Number of nodes in left child:  59 Number of nodes in right child:  43
# Key:
#  chlorides
# Number of nodes in left child:  35 Number of nodes in right child:  67
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  57 Number of nodes in right child:  45
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  52 Number of nodes in right child:  50
# Key:
#  density
# Number of nodes in left child:  51 Number of nodes in right child:  51
# Key:
#  pH
# Number of nodes in left child:  56 Number of nodes in right child:  46
# Key:
#  sulphates
# Number of nodes in left child:  54 Number of nodes in right child:  48
# Key:
#  alcohol
# Number of nodes in left child:  51 Number of nodes in right child:  51
# Optimal attribute to be used to split is : sulphates   5
# Number of nodes in left child:  54 Number of nodes in right child:  48
# Key:
#  fixed acidity
# Number of nodes in left child:  42 Number of nodes in right child:  43
# Key:
#  volatile acidity
# Number of nodes in left child:  53 Number of nodes in right child:  32
# Key:
#  citric acid
# Number of nodes in left child:  46 Number of nodes in right child:  39
# Key:
#  residual sugar
# Number of nodes in left child:  47 Number of nodes in right child:  38
# Key:
#  chlorides
# Number of nodes in left child:  54 Number of nodes in right child:  31
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  58 Number of nodes in right child:  27
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  45 Number of nodes in right child:  40
# Key:
#  density
# Number of nodes in left child:  44 Number of nodes in right child:  41
# Key:
#  pH
# Number of nodes in left child:  46 Number of nodes in right child:  39
# Key:
#  sulphates
# Number of nodes in left child:  50 Number of nodes in right child:  35
# Key:
#  alcohol
# Number of nodes in left child:  56 Number of nodes in right child:  29
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  45 Number of nodes in right child:  40
# Training Complete
#
# 9    Training Start
# Key:
#  fixed acidity
# Number of nodes in left child:  2311 Number of nodes in right child:  2096
# Key:
#  volatile acidity
# Number of nodes in left child:  2452 Number of nodes in right child:  1955
# Key:
#  citric acid
# Number of nodes in left child:  2500 Number of nodes in right child:  1907
# Key:
#  residual sugar
# Number of nodes in left child:  2481 Number of nodes in right child:  1926
# Key:
#  chlorides
# Number of nodes in left child:  2679 Number of nodes in right child:  1728
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  2399 Number of nodes in right child:  2008
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  2340 Number of nodes in right child:  2067
# Key:
#  density
# Number of nodes in left child:  2357 Number of nodes in right child:  2050
# Key:
#  pH
# Number of nodes in left child:  2382 Number of nodes in right child:  2025
# Key:
#  sulphates
# Number of nodes in left child:  2384 Number of nodes in right child:  2023
# Key:
#  alcohol
# Number of nodes in left child:  2474 Number of nodes in right child:  1933
# Optimal attribute to be used to split is : alcohol   0
# Number of nodes in left child:  2474 Number of nodes in right child:  1933
# Key:
#  fixed acidity
# Number of nodes in left child:  1373 Number of nodes in right child:  1101
# Key:
#  volatile acidity
# Number of nodes in left child:  1412 Number of nodes in right child:  1062
# Key:
#  citric acid
# Number of nodes in left child:  1476 Number of nodes in right child:  998
# Key:
#  residual sugar
# Number of nodes in left child:  1289 Number of nodes in right child:  1185
# Key:
#  chlorides
# Number of nodes in left child:  1704 Number of nodes in right child:  770
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  1294 Number of nodes in right child:  1180
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  1230 Number of nodes in right child:  1244
# Key:
#  density
# Number of nodes in left child:  1329 Number of nodes in right child:  1145
# Key:
#  pH
# Number of nodes in left child:  1345 Number of nodes in right child:  1129
# Key:
#  sulphates
# Number of nodes in left child:  1369 Number of nodes in right child:  1105
# Key:
#  alcohol
# Number of nodes in left child:  1292 Number of nodes in right child:  1182
# Optimal attribute to be used to split is : volatile acidity   1
# Number of nodes in left child:  1412 Number of nodes in right child:  1062
# Key:
#  fixed acidity
# Number of nodes in left child:  751 Number of nodes in right child:  661
# Key:
#  volatile acidity
# Number of nodes in left child:  654 Number of nodes in right child:  758
# Key:
#  citric acid
# Number of nodes in left child:  876 Number of nodes in right child:  536
# Key:
#  residual sugar
# Number of nodes in left child:  729 Number of nodes in right child:  683
# Key:
#  chlorides
# Number of nodes in left child:  887 Number of nodes in right child:  525
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  723 Number of nodes in right child:  689
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  703 Number of nodes in right child:  709
# Key:
#  density
# Number of nodes in left child:  739 Number of nodes in right child:  673
# Key:
#  pH
# Number of nodes in left child:  745 Number of nodes in right child:  667
# Key:
#  sulphates
# Number of nodes in left child:  807 Number of nodes in right child:  605
# Key:
#  alcohol
# Number of nodes in left child:  728 Number of nodes in right child:  684
# Optimal attribute to be used to split is : volatile acidity   2
# Number of nodes in left child:  654 Number of nodes in right child:  758
# Key:
#  fixed acidity
# Number of nodes in left child:  355 Number of nodes in right child:  299
# Key:
#  volatile acidity
# Number of nodes in left child:  275 Number of nodes in right child:  379
# Key:
#  citric acid
# Number of nodes in left child:  410 Number of nodes in right child:  244
# Key:
#  residual sugar
# Number of nodes in left child:  367 Number of nodes in right child:  287
# Key:
#  chlorides
# Number of nodes in left child:  405 Number of nodes in right child:  249
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  345 Number of nodes in right child:  309
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  332 Number of nodes in right child:  322
# Key:
#  density
# Number of nodes in left child:  357 Number of nodes in right child:  297
# Key:
#  pH
# Number of nodes in left child:  339 Number of nodes in right child:  315
# Key:
#  sulphates
# Number of nodes in left child:  364 Number of nodes in right child:  290
# Key:
#  alcohol
# Number of nodes in left child:  309 Number of nodes in right child:  345
# Optimal attribute to be used to split is : residual sugar   3
# Number of nodes in left child:  367 Number of nodes in right child:  287
# Key:
#  fixed acidity
# Number of nodes in left child:  200 Number of nodes in right child:  167
# Key:
#  volatile acidity
# Number of nodes in left child:  181 Number of nodes in right child:  186
# Key:
#  citric acid
# Number of nodes in left child:  233 Number of nodes in right child:  134
# Key:
#  residual sugar
# Number of nodes in left child:  252 Number of nodes in right child:  115
# Key:
#  chlorides
# Number of nodes in left child:  250 Number of nodes in right child:  117
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  198 Number of nodes in right child:  169
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  196 Number of nodes in right child:  171
# Key:
#  density
# Number of nodes in left child:  194 Number of nodes in right child:  173
# Key:
#  pH
# Number of nodes in left child:  182 Number of nodes in right child:  185
# Key:
#  sulphates
# Number of nodes in left child:  215 Number of nodes in right child:  152
# Key:
#  alcohol
# Number of nodes in left child:  166 Number of nodes in right child:  201
# Optimal attribute to be used to split is : sulphates   4
# Number of nodes in left child:  215 Number of nodes in right child:  152
# Key:
#  fixed acidity
# Number of nodes in left child:  116 Number of nodes in right child:  99
# Key:
#  volatile acidity
# Number of nodes in left child:  110 Number of nodes in right child:  105
# Key:
#  citric acid
# Number of nodes in left child:  138 Number of nodes in right child:  77
# Key:
#  residual sugar
# Number of nodes in left child:  140 Number of nodes in right child:  75
# Key:
#  chlorides
# Number of nodes in left child:  164 Number of nodes in right child:  51
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  113 Number of nodes in right child:  102
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  108 Number of nodes in right child:  107
# Key:
#  density
# Number of nodes in left child:  108 Number of nodes in right child:  107
# Key:
#  pH
# Number of nodes in left child:  106 Number of nodes in right child:  109
# Key:
#  sulphates
# Number of nodes in left child:  98 Number of nodes in right child:  117
# Key:
#  alcohol
# Number of nodes in left child:  103 Number of nodes in right child:  112
# Optimal attribute to be used to split is : chlorides   5
# Number of nodes in left child:  164 Number of nodes in right child:  51
# Key:
#  fixed acidity
# Number of nodes in left child:  74 Number of nodes in right child:  78
# Key:
#  volatile acidity
# Number of nodes in left child:  71 Number of nodes in right child:  81
# Key:
#  citric acid
# Number of nodes in left child:  95 Number of nodes in right child:  57
# Key:
#  residual sugar
# Number of nodes in left child:  112 Number of nodes in right child:  40
# Key:
#  chlorides
# Number of nodes in left child:  84 Number of nodes in right child:  68
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  85 Number of nodes in right child:  67
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  85 Number of nodes in right child:  67
# Key:
#  density
# Number of nodes in left child:  87 Number of nodes in right child:  65
# Key:
#  pH
# Number of nodes in left child:  75 Number of nodes in right child:  77
# Key:
#  sulphates
# Number of nodes in left child:  93 Number of nodes in right child:  59
# Key:
#  alcohol
# Number of nodes in left child:  68 Number of nodes in right child:  84
# Optimal attribute to be used to split is : free sulfur dioxide   5
# Number of nodes in left child:  85 Number of nodes in right child:  67
# Key:
#  fixed acidity
# Number of nodes in left child:  155 Number of nodes in right child:  132
# Key:
#  volatile acidity
# Number of nodes in left child:  141 Number of nodes in right child:  146
# Key:
#  citric acid
# Number of nodes in left child:  186 Number of nodes in right child:  101
# Key:
#  residual sugar
# Number of nodes in left child:  143 Number of nodes in right child:  144
# Key:
#  chlorides
# Number of nodes in left child:  155 Number of nodes in right child:  132
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  145 Number of nodes in right child:  142
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  154 Number of nodes in right child:  133
# Key:
#  density
# Number of nodes in left child:  149 Number of nodes in right child:  138
# Key:
#  pH
# Number of nodes in left child:  155 Number of nodes in right child:  132
# Key:
#  sulphates
# Number of nodes in left child:  168 Number of nodes in right child:  119
# Key:
#  alcohol
# Number of nodes in left child:  159 Number of nodes in right child:  128
# Optimal attribute to be used to split is : residual sugar   4
# Number of nodes in left child:  143 Number of nodes in right child:  144
# Key:
#  fixed acidity
# Number of nodes in left child:  77 Number of nodes in right child:  66
# Key:
#  volatile acidity
# Number of nodes in left child:  71 Number of nodes in right child:  72
# Key:
#  citric acid
# Number of nodes in left child:  96 Number of nodes in right child:  47
# Key:
#  residual sugar
# Number of nodes in left child:  73 Number of nodes in right child:  70
# Key:
#  chlorides
# Number of nodes in left child:  85 Number of nodes in right child:  58
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  77 Number of nodes in right child:  66
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  74 Number of nodes in right child:  69
# Key:
#  density
# Number of nodes in left child:  80 Number of nodes in right child:  63
# Key:
#  pH
# Number of nodes in left child:  75 Number of nodes in right child:  68
# Key:
#  sulphates
# Number of nodes in left child:  78 Number of nodes in right child:  65
# Key:
#  alcohol
# Number of nodes in left child:  63 Number of nodes in right child:  80
# Optimal attribute to be used to split is : pH   5
# Number of nodes in left child:  75 Number of nodes in right child:  68
# Key:
#  fixed acidity
# Number of nodes in left child:  78 Number of nodes in right child:  66
# Key:
#  volatile acidity
# Number of nodes in left child:  70 Number of nodes in right child:  74
# Key:
#  citric acid
# Number of nodes in left child:  88 Number of nodes in right child:  56
# Key:
#  residual sugar
# Number of nodes in left child:  96 Number of nodes in right child:  48
# Key:
#  chlorides
# Number of nodes in left child:  74 Number of nodes in right child:  70
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  70 Number of nodes in right child:  74
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  81 Number of nodes in right child:  63
# Key:
#  density
# Number of nodes in left child:  72 Number of nodes in right child:  72
# Key:
#  pH
# Number of nodes in left child:  71 Number of nodes in right child:  73
# Key:
#  sulphates
# Number of nodes in left child:  98 Number of nodes in right child:  46
# Key:
#  alcohol
# Number of nodes in left child:  103 Number of nodes in right child:  41
# Optimal attribute to be used to split is : chlorides   5
# Number of nodes in left child:  74 Number of nodes in right child:  70
# Key:
#  fixed acidity
# Number of nodes in left child:  445 Number of nodes in right child:  313
# Key:
#  volatile acidity
# Number of nodes in left child:  367 Number of nodes in right child:  391
# Key:
#  citric acid
# Number of nodes in left child:  446 Number of nodes in right child:  312
# Key:
#  residual sugar
# Number of nodes in left child:  395 Number of nodes in right child:  363
# Key:
#  chlorides
# Number of nodes in left child:  504 Number of nodes in right child:  254
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  380 Number of nodes in right child:  378
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  377 Number of nodes in right child:  381
# Key:
#  density
# Number of nodes in left child:  397 Number of nodes in right child:  361
# Key:
#  pH
# Number of nodes in left child:  403 Number of nodes in right child:  355
# Key:
#  sulphates
# Number of nodes in left child:  414 Number of nodes in right child:  344
# Key:
#  alcohol
# Number of nodes in left child:  405 Number of nodes in right child:  353
# Optimal attribute to be used to split is : fixed acidity   3
# Number of nodes in left child:  445 Number of nodes in right child:  313
# Key:
#  fixed acidity
# Number of nodes in left child:  166 Number of nodes in right child:  279
# Key:
#  volatile acidity
# Number of nodes in left child:  196 Number of nodes in right child:  249
# Key:
#  citric acid
# Number of nodes in left child:  265 Number of nodes in right child:  180
# Key:
#  residual sugar
# Number of nodes in left child:  254 Number of nodes in right child:  191
# Key:
#  chlorides
# Number of nodes in left child:  324 Number of nodes in right child:  121
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  230 Number of nodes in right child:  215
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  230 Number of nodes in right child:  215
# Key:
#  density
# Number of nodes in left child:  229 Number of nodes in right child:  216
# Key:
#  pH
# Number of nodes in left child:  247 Number of nodes in right child:  198
# Key:
#  sulphates
# Number of nodes in left child:  254 Number of nodes in right child:  191
# Key:
#  alcohol
# Number of nodes in left child:  248 Number of nodes in right child:  197
# Optimal attribute to be used to split is : alcohol   4
# Number of nodes in left child:  248 Number of nodes in right child:  197
# Key:
#  fixed acidity
# Number of nodes in left child:  111 Number of nodes in right child:  137
# Key:
#  volatile acidity
# Number of nodes in left child:  115 Number of nodes in right child:  133
# Key:
#  citric acid
# Number of nodes in left child:  138 Number of nodes in right child:  110
# Key:
#  residual sugar
# Number of nodes in left child:  135 Number of nodes in right child:  113
# Key:
#  chlorides
# Number of nodes in left child:  192 Number of nodes in right child:  56
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  119 Number of nodes in right child:  129
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  123 Number of nodes in right child:  125
# Key:
#  density
# Number of nodes in left child:  138 Number of nodes in right child:  110
# Key:
#  pH
# Number of nodes in left child:  119 Number of nodes in right child:  129
# Key:
#  sulphates
# Number of nodes in left child:  119 Number of nodes in right child:  129
# Key:
#  alcohol
# Number of nodes in left child:  117 Number of nodes in right child:  131
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  123 Number of nodes in right child:  125
# Key:
#  fixed acidity
# Number of nodes in left child:  81 Number of nodes in right child:  116
# Key:
#  volatile acidity
# Number of nodes in left child:  81 Number of nodes in right child:  116
# Key:
#  citric acid
# Number of nodes in left child:  104 Number of nodes in right child:  93
# Key:
#  residual sugar
# Number of nodes in left child:  98 Number of nodes in right child:  99
# Key:
#  chlorides
# Number of nodes in left child:  132 Number of nodes in right child:  65
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  112 Number of nodes in right child:  85
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  95 Number of nodes in right child:  102
# Key:
#  density
# Number of nodes in left child:  106 Number of nodes in right child:  91
# Key:
#  pH
# Number of nodes in left child:  110 Number of nodes in right child:  87
# Key:
#  sulphates
# Number of nodes in left child:  110 Number of nodes in right child:  87
# Key:
#  alcohol
# Number of nodes in left child:  92 Number of nodes in right child:  105
# Optimal attribute to be used to split is : pH   5
# Number of nodes in left child:  110 Number of nodes in right child:  87
# Key:
#  fixed acidity
# Number of nodes in left child:  196 Number of nodes in right child:  117
# Key:
#  volatile acidity
# Number of nodes in left child:  170 Number of nodes in right child:  143
# Key:
#  citric acid
# Number of nodes in left child:  194 Number of nodes in right child:  119
# Key:
#  residual sugar
# Number of nodes in left child:  140 Number of nodes in right child:  173
# Key:
#  chlorides
# Number of nodes in left child:  168 Number of nodes in right child:  145
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  157 Number of nodes in right child:  156
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  144 Number of nodes in right child:  169
# Key:
#  density
# Number of nodes in left child:  142 Number of nodes in right child:  171
# Key:
#  pH
# Number of nodes in left child:  182 Number of nodes in right child:  131
# Key:
#  sulphates
# Number of nodes in left child:  173 Number of nodes in right child:  140
# Key:
#  alcohol
# Number of nodes in left child:  157 Number of nodes in right child:  156
# Optimal attribute to be used to split is : density   4
# Number of nodes in left child:  142 Number of nodes in right child:  171
# Key:
#  fixed acidity
# Number of nodes in left child:  84 Number of nodes in right child:  58
# Key:
#  volatile acidity
# Number of nodes in left child:  81 Number of nodes in right child:  61
# Key:
#  citric acid
# Number of nodes in left child:  84 Number of nodes in right child:  58
# Key:
#  residual sugar
# Number of nodes in left child:  74 Number of nodes in right child:  68
# Key:
#  chlorides
# Number of nodes in left child:  77 Number of nodes in right child:  65
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  76 Number of nodes in right child:  66
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  74 Number of nodes in right child:  68
# Key:
#  density
# Number of nodes in left child:  68 Number of nodes in right child:  74
# Key:
#  pH
# Number of nodes in left child:  82 Number of nodes in right child:  60
# Key:
#  sulphates
# Number of nodes in left child:  69 Number of nodes in right child:  73
# Key:
#  alcohol
# Number of nodes in left child:  66 Number of nodes in right child:  76
# Optimal attribute to be used to split is : pH   5
# Number of nodes in left child:  82 Number of nodes in right child:  60
# Key:
#  fixed acidity
# Number of nodes in left child:  112 Number of nodes in right child:  59
# Key:
#  volatile acidity
# Number of nodes in left child:  89 Number of nodes in right child:  82
# Key:
#  citric acid
# Number of nodes in left child:  102 Number of nodes in right child:  69
# Key:
#  residual sugar
# Number of nodes in left child:  81 Number of nodes in right child:  90
# Key:
#  chlorides
# Number of nodes in left child:  107 Number of nodes in right child:  64
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  85 Number of nodes in right child:  86
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  78 Number of nodes in right child:  93
# Key:
#  density
# Number of nodes in left child:  92 Number of nodes in right child:  79
# Key:
#  pH
# Number of nodes in left child:  101 Number of nodes in right child:  70
# Key:
#  sulphates
# Number of nodes in left child:  97 Number of nodes in right child:  74
# Key:
#  alcohol
# Number of nodes in left child:  116 Number of nodes in right child:  55
# Optimal attribute to be used to split is : density   5
# Number of nodes in left child:  92 Number of nodes in right child:  79
# Key:
#  fixed acidity
# Number of nodes in left child:  622 Number of nodes in right child:  440
# Key:
#  volatile acidity
# Number of nodes in left child:  711 Number of nodes in right child:  351
# Key:
#  citric acid
# Number of nodes in left child:  585 Number of nodes in right child:  477
# Key:
#  residual sugar
# Number of nodes in left child:  560 Number of nodes in right child:  502
# Key:
#  chlorides
# Number of nodes in left child:  800 Number of nodes in right child:  262
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  580 Number of nodes in right child:  482
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  504 Number of nodes in right child:  558
# Key:
#  density
# Number of nodes in left child:  563 Number of nodes in right child:  499
# Key:
#  pH
# Number of nodes in left child:  608 Number of nodes in right child:  454
# Key:
#  sulphates
# Number of nodes in left child:  562 Number of nodes in right child:  500
# Key:
#  alcohol
# Number of nodes in left child:  620 Number of nodes in right child:  442
# Optimal attribute to be used to split is : sulphates   2
# Number of nodes in left child:  562 Number of nodes in right child:  500
# Key:
#  fixed acidity
# Number of nodes in left child:  320 Number of nodes in right child:  242
# Key:
#  volatile acidity
# Number of nodes in left child:  378 Number of nodes in right child:  184
# Key:
#  citric acid
# Number of nodes in left child:  327 Number of nodes in right child:  235
# Key:
#  residual sugar
# Number of nodes in left child:  293 Number of nodes in right child:  269
# Key:
#  chlorides
# Number of nodes in left child:  416 Number of nodes in right child:  146
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  311 Number of nodes in right child:  251
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  277 Number of nodes in right child:  285
# Key:
#  density
# Number of nodes in left child:  311 Number of nodes in right child:  251
# Key:
#  pH
# Number of nodes in left child:  295 Number of nodes in right child:  267
# Key:
#  sulphates
# Number of nodes in left child:  223 Number of nodes in right child:  339
# Key:
#  alcohol
# Number of nodes in left child:  314 Number of nodes in right child:  248
# Optimal attribute to be used to split is : pH   3
# Number of nodes in left child:  295 Number of nodes in right child:  267
# Key:
#  fixed acidity
# Number of nodes in left child:  172 Number of nodes in right child:  123
# Key:
#  volatile acidity
# Number of nodes in left child:  203 Number of nodes in right child:  92
# Key:
#  citric acid
# Number of nodes in left child:  150 Number of nodes in right child:  145
# Key:
#  residual sugar
# Number of nodes in left child:  154 Number of nodes in right child:  141
# Key:
#  chlorides
# Number of nodes in left child:  232 Number of nodes in right child:  63
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  157 Number of nodes in right child:  138
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  138 Number of nodes in right child:  157
# Key:
#  density
# Number of nodes in left child:  160 Number of nodes in right child:  135
# Key:
#  pH
# Number of nodes in left child:  105 Number of nodes in right child:  190
# Key:
#  sulphates
# Number of nodes in left child:  113 Number of nodes in right child:  182
# Key:
#  alcohol
# Number of nodes in left child:  152 Number of nodes in right child:  143
# Optimal attribute to be used to split is : fixed acidity   4
# Number of nodes in left child:  172 Number of nodes in right child:  123
# Key:
#  fixed acidity
# Number of nodes in left child:  81 Number of nodes in right child:  91
# Key:
#  volatile acidity
# Number of nodes in left child:  109 Number of nodes in right child:  63
# Key:
#  citric acid
# Number of nodes in left child:  88 Number of nodes in right child:  84
# Key:
#  residual sugar
# Number of nodes in left child:  95 Number of nodes in right child:  77
# Key:
#  chlorides
# Number of nodes in left child:  135 Number of nodes in right child:  37
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  95 Number of nodes in right child:  77
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  85 Number of nodes in right child:  87
# Key:
#  density
# Number of nodes in left child:  85 Number of nodes in right child:  87
# Key:
#  pH
# Number of nodes in left child:  58 Number of nodes in right child:  114
# Key:
#  sulphates
# Number of nodes in left child:  66 Number of nodes in right child:  106
# Key:
#  alcohol
# Number of nodes in left child:  89 Number of nodes in right child:  83
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  81 Number of nodes in right child:  91
# Key:
#  fixed acidity
# Number of nodes in left child:  83 Number of nodes in right child:  40
# Key:
#  volatile acidity
# Number of nodes in left child:  87 Number of nodes in right child:  36
# Key:
#  citric acid
# Number of nodes in left child:  64 Number of nodes in right child:  59
# Key:
#  residual sugar
# Number of nodes in left child:  59 Number of nodes in right child:  64
# Key:
#  chlorides
# Number of nodes in left child:  92 Number of nodes in right child:  31
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  62 Number of nodes in right child:  61
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  55 Number of nodes in right child:  68
# Key:
#  density
# Number of nodes in left child:  59 Number of nodes in right child:  64
# Key:
#  pH
# Number of nodes in left child:  47 Number of nodes in right child:  76
# Key:
#  sulphates
# Number of nodes in left child:  52 Number of nodes in right child:  71
# Key:
#  alcohol
# Number of nodes in left child:  71 Number of nodes in right child:  52
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  83 Number of nodes in right child:  40
# Key:
#  fixed acidity
# Number of nodes in left child:  155 Number of nodes in right child:  112
# Key:
#  volatile acidity
# Number of nodes in left child:  177 Number of nodes in right child:  90
# Key:
#  citric acid
# Number of nodes in left child:  145 Number of nodes in right child:  122
# Key:
#  residual sugar
# Number of nodes in left child:  126 Number of nodes in right child:  141
# Key:
#  chlorides
# Number of nodes in left child:  188 Number of nodes in right child:  79
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  153 Number of nodes in right child:  114
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  141 Number of nodes in right child:  126
# Key:
#  density
# Number of nodes in left child:  146 Number of nodes in right child:  121
# Key:
#  pH
# Number of nodes in left child:  175 Number of nodes in right child:  92
# Key:
#  sulphates
# Number of nodes in left child:  110 Number of nodes in right child:  157
# Key:
#  alcohol
# Number of nodes in left child:  155 Number of nodes in right child:  112
# Optimal attribute to be used to split is : total sulfur dioxide   4
# Number of nodes in left child:  141 Number of nodes in right child:  126
# Key:
#  fixed acidity
# Number of nodes in left child:  78 Number of nodes in right child:  63
# Key:
#  volatile acidity
# Number of nodes in left child:  88 Number of nodes in right child:  53
# Key:
#  citric acid
# Number of nodes in left child:  70 Number of nodes in right child:  71
# Key:
#  residual sugar
# Number of nodes in left child:  76 Number of nodes in right child:  65
# Key:
#  chlorides
# Number of nodes in left child:  85 Number of nodes in right child:  56
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  71 Number of nodes in right child:  70
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  61 Number of nodes in right child:  80
# Key:
#  density
# Number of nodes in left child:  77 Number of nodes in right child:  64
# Key:
#  pH
# Number of nodes in left child:  85 Number of nodes in right child:  56
# Key:
#  sulphates
# Number of nodes in left child:  72 Number of nodes in right child:  69
# Key:
#  alcohol
# Number of nodes in left child:  76 Number of nodes in right child:  65
# Optimal attribute to be used to split is : alcohol   5
# Number of nodes in left child:  76 Number of nodes in right child:  65
# Key:
#  fixed acidity
# Number of nodes in left child:  69 Number of nodes in right child:  57
# Key:
#  volatile acidity
# Number of nodes in left child:  83 Number of nodes in right child:  43
# Key:
#  citric acid
# Number of nodes in left child:  74 Number of nodes in right child:  52
# Key:
#  residual sugar
# Number of nodes in left child:  74 Number of nodes in right child:  52
# Key:
#  chlorides
# Number of nodes in left child:  90 Number of nodes in right child:  36
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  56 Number of nodes in right child:  70
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  68 Number of nodes in right child:  58
# Key:
#  density
# Number of nodes in left child:  73 Number of nodes in right child:  53
# Key:
#  pH
# Number of nodes in left child:  88 Number of nodes in right child:  38
# Key:
#  sulphates
# Number of nodes in left child:  64 Number of nodes in right child:  62
# Key:
#  alcohol
# Number of nodes in left child:  70 Number of nodes in right child:  56
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  69 Number of nodes in right child:  57
# Key:
#  fixed acidity
# Number of nodes in left child:  269 Number of nodes in right child:  231
# Key:
#  volatile acidity
# Number of nodes in left child:  335 Number of nodes in right child:  165
# Key:
#  citric acid
# Number of nodes in left child:  276 Number of nodes in right child:  224
# Key:
#  residual sugar
# Number of nodes in left child:  254 Number of nodes in right child:  246
# Key:
#  chlorides
# ...
# Key:
#  fixed acidity
# Number of nodes in left child:  228 Number of nodes in right child:  234
# Key:
#  volatile acidity
# Number of nodes in left child:  263 Number of nodes in right child:  199
# Key:
#  citric acid
# Number of nodes in left child:  290 Number of nodes in right child:  172
# Key:
#  residual sugar
# Number of nodes in left child:  290 Number of nodes in right child:  172
# Key:
#  chlorides
# Number of nodes in left child:  256 Number of nodes in right child:  206
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  237 Number of nodes in right child:  225
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  247 Number of nodes in right child:  215
# Key:
#  density
# Number of nodes in left child:  281 Number of nodes in right child:  181
# Key:
#  pH
# Number of nodes in left child:  254 Number of nodes in right child:  208
# Key:
#  sulphates
# Number of nodes in left child:  277 Number of nodes in right child:  185
# Key:
#  alcohol
# Number of nodes in left child:  190 Number of nodes in right child:  272
# Optimal attribute to be used to split is : total sulfur dioxide   3
# Number of nodes in left child:  247 Number of nodes in right child:  215
# Key:
#  fixed acidity
# Number of nodes in left child:  137 Number of nodes in right child:  110
# Key:
#  volatile acidity
# Number of nodes in left child:  138 Number of nodes in right child:  109
# Key:
#  citric acid
# Number of nodes in left child:  134 Number of nodes in right child:  113
# Key:
#  residual sugar
# Number of nodes in left child:  159 Number of nodes in right child:  88
# Key:
#  chlorides
# Number of nodes in left child:  128 Number of nodes in right child:  119
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  129 Number of nodes in right child:  118
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  105 Number of nodes in right child:  142
# Key:
#  density
# Number of nodes in left child:  139 Number of nodes in right child:  108
# Key:
#  pH
# Number of nodes in left child:  130 Number of nodes in right child:  117
# Key:
#  sulphates
# Number of nodes in left child:  144 Number of nodes in right child:  103
# Key:
#  alcohol
# Number of nodes in left child:  112 Number of nodes in right child:  135
# Optimal attribute to be used to split is : total sulfur dioxide   4
# Number of nodes in left child:  105 Number of nodes in right child:  142
# Key:
#  fixed acidity
# Number of nodes in left child:  55 Number of nodes in right child:  50
# Key:
#  volatile acidity
# Number of nodes in left child:  60 Number of nodes in right child:  45
# Key:
#  citric acid
# Number of nodes in left child:  56 Number of nodes in right child:  49
# Key:
#  residual sugar
# Number of nodes in left child:  69 Number of nodes in right child:  36
# Key:
#  chlorides
# Number of nodes in left child:  58 Number of nodes in right child:  47
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  54 Number of nodes in right child:  51
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  41 Number of nodes in right child:  64
# Key:
#  density
# Number of nodes in left child:  64 Number of nodes in right child:  41
# Key:
#  pH
# Number of nodes in left child:  52 Number of nodes in right child:  53
# Key:
#  sulphates
# Number of nodes in left child:  59 Number of nodes in right child:  46
# Key:
#  alcohol
# Number of nodes in left child:  51 Number of nodes in right child:  54
# Optimal attribute to be used to split is : sulphates   5
# Number of nodes in left child:  59 Number of nodes in right child:  46
# Key:
#  fixed acidity
# Number of nodes in left child:  73 Number of nodes in right child:  69
# Key:
#  volatile acidity
# Number of nodes in left child:  74 Number of nodes in right child:  68
# Key:
#  citric acid
# Number of nodes in left child:  78 Number of nodes in right child:  64
# Key:
#  residual sugar
# Number of nodes in left child:  88 Number of nodes in right child:  54
# Key:
#  chlorides
# Number of nodes in left child:  70 Number of nodes in right child:  72
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  68 Number of nodes in right child:  74
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  77 Number of nodes in right child:  65
# Key:
#  density
# Number of nodes in left child:  79 Number of nodes in right child:  63
# Key:
#  pH
# Number of nodes in left child:  78 Number of nodes in right child:  64
# Key:
#  sulphates
# Number of nodes in left child:  84 Number of nodes in right child:  58
# Key:
#  alcohol
# Number of nodes in left child:  61 Number of nodes in right child:  81
# Optimal attribute to be used to split is : volatile acidity   5
# Number of nodes in left child:  74 Number of nodes in right child:  68
# Key:
#  fixed acidity
# Number of nodes in left child:  103 Number of nodes in right child:  112
# Key:
#  volatile acidity
# Number of nodes in left child:  118 Number of nodes in right child:  97
# Key:
#  citric acid
# Number of nodes in left child:  147 Number of nodes in right child:  68
# Key:
#  residual sugar
# Number of nodes in left child:  136 Number of nodes in right child:  79
# Key:
#  chlorides
# Number of nodes in left child:  124 Number of nodes in right child:  91
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  116 Number of nodes in right child:  99
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  123 Number of nodes in right child:  92
# Key:
#  density
# Number of nodes in left child:  137 Number of nodes in right child:  78
# Key:
#  pH
# Number of nodes in left child:  118 Number of nodes in right child:  97
# Key:
#  sulphates
# Number of nodes in left child:  133 Number of nodes in right child:  82
# Key:
#  alcohol
# Number of nodes in left child:  78 Number of nodes in right child:  137
# Optimal attribute to be used to split is : chlorides   4
# Number of nodes in left child:  124 Number of nodes in right child:  91
# Key:
#  fixed acidity
# Number of nodes in left child:  62 Number of nodes in right child:  62
# Key:
#  volatile acidity
# Number of nodes in left child:  71 Number of nodes in right child:  53
# Key:
#  citric acid
# Number of nodes in left child:  72 Number of nodes in right child:  52
# Key:
#  residual sugar
# Number of nodes in left child:  70 Number of nodes in right child:  54
# Key:
#  chlorides
# Number of nodes in left child:  53 Number of nodes in right child:  71
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  65 Number of nodes in right child:  59
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  75 Number of nodes in right child:  49
# Key:
#  density
# Number of nodes in left child:  76 Number of nodes in right child:  48
# Key:
#  pH
# Number of nodes in left child:  72 Number of nodes in right child:  52
# Key:
#  sulphates
# Number of nodes in left child:  80 Number of nodes in right child:  44
# Key:
#  alcohol
# Number of nodes in left child:  71 Number of nodes in right child:  53
# Optimal attribute to be used to split is : free sulfur dioxide   5
# Number of nodes in left child:  65 Number of nodes in right child:  59
# Key:
#  fixed acidity
# Number of nodes in left child:  41 Number of nodes in right child:  50
# Key:
#  volatile acidity
# Number of nodes in left child:  46 Number of nodes in right child:  45
# Key:
#  citric acid
# Number of nodes in left child:  63 Number of nodes in right child:  28
# Key:
#  residual sugar
# Number of nodes in left child:  63 Number of nodes in right child:  28
# Key:
#  chlorides
# Number of nodes in left child:  64 Number of nodes in right child:  27
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  52 Number of nodes in right child:  39
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  48 Number of nodes in right child:  43
# Key:
#  density
# Number of nodes in left child:  61 Number of nodes in right child:  30
# Key:
#  pH
# Number of nodes in left child:  45 Number of nodes in right child:  46
# Key:
#  sulphates
# Number of nodes in left child:  53 Number of nodes in right child:  38
# Key:
#  alcohol
# Number of nodes in left child:  40 Number of nodes in right child:  51
# Optimal attribute to be used to split is : fixed acidity   5
# Number of nodes in left child:  41 Number of nodes in right child:  50
# Key:
#  fixed acidity
# Number of nodes in left child:  211 Number of nodes in right child:  214
# Key:
#  volatile acidity
# Number of nodes in left child:  244 Number of nodes in right child:  181
# Key:
#  citric acid
# Number of nodes in left child:  227 Number of nodes in right child:  198
# Key:
#  residual sugar
# Number of nodes in left child:  247 Number of nodes in right child:  178
# Key:
#  chlorides
# Number of nodes in left child:  248 Number of nodes in right child:  177
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  217 Number of nodes in right child:  208
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  216 Number of nodes in right child:  209
# Key:
#  density
# Number of nodes in left child:  230 Number of nodes in right child:  195
# Key:
#  pH
# Number of nodes in left child:  209 Number of nodes in right child:  216
# Key:
#  sulphates
# Number of nodes in left child:  248 Number of nodes in right child:  177
# Key:
#  alcohol
# Number of nodes in left child:  239 Number of nodes in right child:  186
# Optimal attribute to be used to split is : alcohol   3
# Number of nodes in left child:  239 Number of nodes in right child:  186
# Key:
#  fixed acidity
# Number of nodes in left child:  121 Number of nodes in right child:  118
# Key:
#  volatile acidity
# Number of nodes in left child:  128 Number of nodes in right child:  111
# Key:
#  citric acid
# Number of nodes in left child:  131 Number of nodes in right child:  108
# Key:
#  residual sugar
# Number of nodes in left child:  135 Number of nodes in right child:  104
# Key:
#  chlorides
# Number of nodes in left child:  133 Number of nodes in right child:  106
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  131 Number of nodes in right child:  108
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  122 Number of nodes in right child:  117
# Key:
#  density
# Number of nodes in left child:  123 Number of nodes in right child:  116
# Key:
#  pH
# Number of nodes in left child:  118 Number of nodes in right child:  121
# Key:
#  sulphates
# Number of nodes in left child:  139 Number of nodes in right child:  100
# Key:
#  alcohol
# Number of nodes in left child:  128 Number of nodes in right child:  111
# Optimal attribute to be used to split is : sulphates   4
# Number of nodes in left child:  139 Number of nodes in right child:  100
# Key:
#  fixed acidity
# Number of nodes in left child:  71 Number of nodes in right child:  68
# Key:
#  volatile acidity
# Number of nodes in left child:  79 Number of nodes in right child:  60
# Key:
#  citric acid
# Number of nodes in left child:  67 Number of nodes in right child:  72
# Key:
#  residual sugar
# Number of nodes in left child:  76 Number of nodes in right child:  63
# Key:
#  chlorides
# Number of nodes in left child:  78 Number of nodes in right child:  61
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  72 Number of nodes in right child:  67
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  67 Number of nodes in right child:  72
# Key:
#  density
# Number of nodes in left child:  75 Number of nodes in right child:  64
# Key:
#  pH
# Number of nodes in left child:  70 Number of nodes in right child:  69
# Key:
#  sulphates
# Number of nodes in left child:  70 Number of nodes in right child:  69
# Key:
#  alcohol
# Number of nodes in left child:  80 Number of nodes in right child:  59
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  67 Number of nodes in right child:  72
# Key:
#  fixed acidity
# Number of nodes in left child:  50 Number of nodes in right child:  50
# Key:
#  volatile acidity
# Number of nodes in left child:  49 Number of nodes in right child:  51
# Key:
#  citric acid
# Number of nodes in left child:  56 Number of nodes in right child:  44
# Key:
#  residual sugar
# Number of nodes in left child:  56 Number of nodes in right child:  44
# Key:
#  chlorides
# Number of nodes in left child:  48 Number of nodes in right child:  52
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  56 Number of nodes in right child:  44
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  54 Number of nodes in right child:  46
# Key:
#  density
# Number of nodes in left child:  52 Number of nodes in right child:  48
# Key:
#  pH
# Number of nodes in left child:  53 Number of nodes in right child:  47
# Key:
#  sulphates
# Number of nodes in left child:  62 Number of nodes in right child:  38
# Key:
#  alcohol
# Number of nodes in left child:  48 Number of nodes in right child:  52
# Optimal attribute to be used to split is : free sulfur dioxide   5
# Number of nodes in left child:  56 Number of nodes in right child:  44
# Key:
#  fixed acidity
# Number of nodes in left child:  89 Number of nodes in right child:  97
# Key:
#  volatile acidity
# Number of nodes in left child:  111 Number of nodes in right child:  75
# Key:
#  citric acid
# Number of nodes in left child:  117 Number of nodes in right child:  69
# Key:
#  residual sugar
# Number of nodes in left child:  112 Number of nodes in right child:  74
# Key:
#  chlorides
# Number of nodes in left child:  115 Number of nodes in right child:  71
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  93 Number of nodes in right child:  93
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  93 Number of nodes in right child:  93
# Key:
#  density
# Number of nodes in left child:  106 Number of nodes in right child:  80
# Key:
#  pH
# Number of nodes in left child:  95 Number of nodes in right child:  91
# Key:
#  sulphates
# Number of nodes in left child:  109 Number of nodes in right child:  77
# Key:
#  alcohol
# Number of nodes in left child:  119 Number of nodes in right child:  67
# Optimal attribute to be used to split is : fixed acidity   4
# Number of nodes in left child:  89 Number of nodes in right child:  97
# Key:
#  fixed acidity
# Number of nodes in left child:  36 Number of nodes in right child:  53
# Key:
#  volatile acidity
# Number of nodes in left child:  54 Number of nodes in right child:  35
# Key:
#  citric acid
# Number of nodes in left child:  42 Number of nodes in right child:  47
# Key:
#  residual sugar
# Number of nodes in left child:  59 Number of nodes in right child:  30
# Key:
#  chlorides
# Number of nodes in left child:  49 Number of nodes in right child:  40
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  40 Number of nodes in right child:  49
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  45 Number of nodes in right child:  44
# Key:
#  density
# Number of nodes in left child:  50 Number of nodes in right child:  39
# Key:
#  pH
# Number of nodes in left child:  45 Number of nodes in right child:  44
# Key:
#  sulphates
# Number of nodes in left child:  53 Number of nodes in right child:  36
# Key:
#  alcohol
# Number of nodes in left child:  55 Number of nodes in right child:  34
# Optimal attribute to be used to split is : total sulfur dioxide   5
# Number of nodes in left child:  45 Number of nodes in right child:  44
# Key:
#  fixed acidity
# Number of nodes in left child:  59 Number of nodes in right child:  38
# Key:
#  volatile acidity
# Number of nodes in left child:  51 Number of nodes in right child:  46
# Key:
#  citric acid
# Number of nodes in left child:  64 Number of nodes in right child:  33
# Key:
#  residual sugar
# Number of nodes in left child:  59 Number of nodes in right child:  38
# Key:
#  chlorides
# Number of nodes in left child:  63 Number of nodes in right child:  34
# Key:
#  free sulfur dioxide
# Number of nodes in left child:  49 Number of nodes in right child:  48
# Key:
#  total sulfur dioxide
# Number of nodes in left child:  47 Number of nodes in right child:  50
# Key:
#  density
# Number of nodes in left child:  57 Number of nodes in right child:  40
# Key:
#  pH
# Number of nodes in left child:  45 Number of nodes in right child:  52
# Key:
#  sulphates
# Number of nodes in left child:  56 Number of nodes in right child:  41
# Key:
#  alcohol
# Number of nodes in left child:  67 Number of nodes in right child:  30
# Optimal attribute to be used to split is : free sulfur dioxide   5
# Number of nodes in left child:  49 Number of nodes in right child:  48
# Training Complete

# %%
accuracy_list
# Out:
# [0.8073770491803278,
#  0.735655737704918,
#  0.75,
#  0.8217213114754098,
#  0.8688524590163934,
#  0.7520491803278688,
#  0.7172131147540983,
#  0.26639344262295084,
#  0.8155737704918032,
#  0.8299180327868853]

# %%
acc=np.sum(accuracy_list)/(10)  #recalculated accuracy

# %%
acc
# Out:
# 0.7364754098360655

# %%
train_data.shape
# Out:
# (4407, 12)

# %%
train_data.head(5)
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.0              0.27         0.36  ...       0.45      8.8        0
# 1            6.3              0.30         0.34  ...       0.49      9.5        0
# 2            8.1              0.28         0.40  ...       0.44     10.1        0
# 3            7.2              0.23         0.32  ...       0.40      9.9        0
# 4            7.2              0.23         0.32  ...       0.40      9.9        0
#
# [5 rows x 12 columns]

# %% [markdown]
# # Decision tree implementation ( with using library sklearn and gini index)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
sk_tree=DecisionTreeClassifier(max_depth=5,criterion="gini")

# %%
data.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
count=0
features=['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
       'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
       'pH', 'sulphates', 'alcohol']
accuracy_list=[]
for k in arr:
    test_data=data[k:k+488]
    if(k==0):
        train_data=data[k+489:]
    else:
        train_data=data[:k-1].append(data[k+490:])
    count=count+1
    sk_tree.fit(train_data[features],train_data['quality'])
    accuracy_list.append(sk_tree.score(test_data[features],test_data['quality']))
print("Accuracy using gini index :",np.mean(accuracy_list))
# Out:
# Accuracy using gini index : 0.8030737704918032
